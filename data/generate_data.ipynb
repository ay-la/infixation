# %%
import csv
import json
import glob
import numpy as np
import pandas as pd
import re
import requests
import string

from bs4 import BeautifulSoup
from pathlib import Path

# %% [markdown]
# # Constructing syllable data

# %%
def get_syllables(word):
    '''
    Returns a word separated into syllables from www.howmanysyllables.com
    '''
    URL = "https://www.howmanysyllables.com/syllables/" + word
    page = requests.get(URL)

    soup = BeautifulSoup(page.content, "html.parser")
    syllable_content = soup.find(id="SyllableContentContainer")
    syllabified_w = syllable_content.find("span", class_="Answer_Red").text
    
    return syllabified_w

def get_syllable_stress(syllables, cmu_entry):
    '''
    Returns a list of tuples of the form (syllable, stress#).
    This represents the stress pattern of the given word.
    '''
    syl_stress = []
    for i in range(len(cmu_entry)):
        stress = re.sub('[^0-9]','', cmu_entry[i])
        syl_stress.append((syllables[i], stress))
    return syl_stress

# %%
cmu_comb = 'K AH2 M - B IH0 N - AH0 - B IH1 - L AH0 - T IY0'
syl_comb = get_syllables('combinability').split('-')

# %%
syl_comb.split('-')
# Out:
# ['com', 'bin', 'a', 'bil', 'i', 'ty']

# %%
cmu = cmu_comb.split('-')
syl_stress = []

for s in range(len(cmu)):
    # delete everything except stress number, zip with syl_comb
    print(cmu[s])
    stress = re.sub('[^0-9]','', cmu[s])
    syl_stress.append((syl_comb[s], stress))
    
syl_stress
# Out:
# K AH2 M
#  B IH0 N
#  AH0
#  B IH1
#  L AH0
#  T IY0
# [('com', '2'), ('bin', '0'), ('a', '0'), ('bil', '1'), ('i', '0'), ('ty', '0')]

# %%
# load cmudict
with open('cmudict.rep') as f:
    lines = f.readlines()

# now exclude any strings containing punctuation besides -, 
exclude = set(string.punctuation.replace('-', ''))

# filter and clean strings
cmu_dict = [s for s in lines if not any(c in s for c in exclude)]
cmu_cleaned = []
for entry in cmu_dict:
    entry = entry.replace('\n', '')
    e = entry.split('  ')
    cmu_cleaned.append((e[0], e[1]))

# %%
def process_data(batch, filename):
    data = []
    with open(filename, 'a') as f:
        for i in range(len(batch)):
            print(str(i) + "/" + str(len(batch)))
            entry = batch[i]
            word = entry[0]
            cmu = entry[1].split('-')
            try:
                syllables = get_syllables(word).split('-')
                if len(syllables) == len(cmu):
                    stress_pattern = get_syllable_stress(syllables, cmu)
                    info = {'word': word, 
                            'num_syllables': str(len(syllables)), 
                            'syllables': syllables, 
                            'stress_pattern': stress_pattern}
                    print(info)
                    data.append(info)
                    f.write(json.dumps(info) + '\n')
            except AttributeError:
                pass
        return data

# %% [markdown]
# # Reading syllable data

# %%
# reading the data from the files and concatenating into a single df

folder_path = 'syllable_data/'
file_list = glob.glob(folder_path + '*.txt')
data = []

for file in file_list:
    with open(file, 'r') as f:
        for line in f:
            d = json.loads(line.strip())
            data.append(d)
            
df = pd.DataFrame(data)

# %%
df['num_syllables'] = pd.to_numeric(df['num_syllables'])

# %%
df.to_csv('all_syllable_data.csv')

# %% [markdown]
# # Generating infix data

# %%
def insert_diddly(df_row):
    syllables = df_row['syllables']
    stress_pattern = df_row['stress_pattern']

    # bisyllabic w/ no reduplication
    if is_bisyllabic(df_row) and not has_initial_stress(df_row):
        return syllables[0] + '-diddly-' + syllables[1]
    # bisyllabic w/ reduplication 
    elif is_bisyllabic(df_row) and has_initial_stress(df_row):
        return diddly_reduplication(syllables, stress_pattern)
        
def diddly_reduplication(syllables, stress_pattern):
    consonants = 'bcdfghjklmnpqrstvwxz'
    vowels = 'aeiouy'
    new_syllables = []
    prefix = ''
    nuc = ''
    primary_stress = False # prevents double infixation for bisyllabic entries with both syllables labeled '1'
    
    for s in stress_pattern:
        syllable = s[0].lower()
        
        if s[1] == '1' and primary_stress == False: 
            primary_stress = True
            # reduplicate entire syllable if starts with vowel
            if syllable.startswith(tuple(vowels)):
                new_syllables.extend([syllable, '-diddly-', syllable])
            else:
                # otherwise reduplicate just the nucleus/coda
                for i in range(len(syllable)):
                    if syllable[i] in consonants:
                        prefix += syllable[i]
                    else:
                        nuc += syllable[i:len(syllable)]
                        break
                new_syllables.extend([prefix + nuc, '-diddly-', nuc])
        else:
            new_syllables.append(syllable)
    
    return ''.join(new_syllables)       
        
def insert_expletive(df_row):
    syllables = df_row['syllables'].copy()
    stress = df_row['stress_pattern'].copy()

    for i in range(len(syllables)):
        if stress[i][1] == '1':
            syllables.insert(i, '-fuckin-')
    return ''.join(syllables)


def insert_iz(df_row):
    word = df_row['word'].lower()
    syllables = df_row['syllables'].copy()
    stress = df_row['stress_pattern'].copy()
    
    if df_row['num_syllables'] == 1:
        # insert between nucleus and onset
        return btwn_nucleus_onset(word, '-iz-')

    elif df_row['num_syllables'] == 2:
        # insert to left of stressed vowel 
        for i in range(len(syllables)):
            if stress[i][1] == '1': 
                syllables[i] = btwn_nucleus_onset(syllables[i], '-iz-')
                print(word, syllables)
        if None in syllables:
            pass
        else:
            return ''.join(syllables)
    
            
def btwn_nucleus_onset(syllable, infix):
    consonants = 'bcdfghjklmnpqrstvwxz'
    vowels = 'aeiouy'
    prefix = ''
    for i in range(len(syllable)):
        if syllable[i] in consonants:
            prefix += syllable[i]
        elif syllable[i] in vowels:
            return syllable[:i] + infix + syllable[i:]

def has_initial_stress(df_row):
    stress = df_row['stress_pattern']
    if stress[0][1] == '1':
        return True
    else:
        return False
    
def is_monosyllabic(df_row):
    if df_row['num_syllables'] == 1:
        return True
    else:
        return False
    
def is_bisyllabic(df_row):
    if df_row['num_syllables'] == 2:
        return True
    else:
        return False

# %%
'''
finding data that's good for expletive infixation:
- minimum bisyllabic
-- bisyllabic: no primary stress on first syllable
-- trisyllabic: primary stress is internal
'''
expletive_data = df.loc[df['num_syllables']>1]
# exclude everything where primary stress is on first syllable
expletive_data = expletive_data[expletive_data['stress_pattern'].apply(lambda x: x[0][1] != '1')] 
expletive_data['infixed'] = expletive_data.apply(insert_expletive, axis=1)
expletive_data.to_csv('expletive_data.csv')

# %%
'''
finding data that's good for iz infixation:
- btwn onset and nucleus of monosyllabic word
-- to the left of a stressed vowel in bisyllabic words
more than that isn't included bc rare
'''
iz_data = df.loc[df['num_syllables']<3]
iz_data['infixed'] = iz_data.apply(insert_iz, axis=1)
iz_data.to_csv('iz_data.csv')
# Out:
# tiber ['T-iz-i', 'ber']
# tibet ['Ti', 'b-iz-et']
# ticker ['t-iz-ick', 'er']
# ticket ['t-iz-ick', 'et']
# tickets ['t-iz-ick', 'ets']
# ticking ['t-iz-ick', 'ing']
# tickle ['t-iz-ick', 'le']
# tickled ['t-iz-ick', 'led']
# ticknor ['T-iz-ick', 'nor']
# tidal ['t-iz-id', 'al']
# tidbit ['t-iz-id', 'bit']
# tiding ['t-iz-id', 'ing']
# tidings ['t-iz-i', 'dings']
# tidy ['t-iz-i', 'dy']
# tiffin ['T-iz-if', 'fin']
# tiger ['t-iz-i', 'ger']
# tigers ['t-iz-i', 'gers']
# tighten ['t-iz-ight', 'en']
# tighter ['t-iz-ight', 'er']
# tightest ['t-iz-ight', 'est']
# tightly ['t-iz-ight', 'ly']
# tightness ['t-iz-ight', 'ness']
# tightrope ['t-iz-ight', 'rope']
# tightwad ['t-iz-ight', 'wad']
# tigon ['t-iz-i', 'gon']
# tigris ['T-iz-i', 'gris']
# tilden ['T-iz-il', 'den']
# tiller ['t-iz-ill', 'er']
# tilley ['t-iz-il', 'ley']
# tillman ['t-iz-ill', 'man']
# tilly ['T-iz-il', 'ly']
# tilted ['t-iz-ilt', 'ed']
# tilting ['t-iz-ilt', 'ing']
# timber ['t-iz-im', 'ber']
# timbre ['t-iz-im', 'bre']
# timeless ['t-iz-ime', 'less']
# timeline ['t-iz-ime', 'line']
# timelines ['t-iz-ime', 'lines']
# timely ['t-iz-ime', 'ly']
# timeout ['t-iz-ime', 'out']
# timepiece ['t-iz-ime', 'piece']
# timer ['t-iz-im', 'er']
# timeshare ['t-iz-ime', 'share']
# timid ['t-iz-im', 'id']
# timing ['t-iz-im', 'ing']
# timmer ['t-iz-im', 'mer']
# timon ['T-iz-i', 'mon']
# timor ['Ti', 'm-iz-or']
# tincture ['t-iz-inc', 'ture']
# tindal ['T-iz-in', 'dal']
# tinder ['t-iz-in', 'der']
# tingle ['t-iz-in', 'gle']
# tinker ['t-iz-in', 'ker']
# tinkle ['t-iz-in', 'kle']
# tinkled ['t-iz-in', 'kled']
# tinman ['t-iz-in', 'man']
# tinny ['t-iz-in', 'ny']
# tinsel ['t-iz-in', 'sel']
# tinto ['t-iz-in', 'to']
# tintype ['t-iz-in', 'type']
# tiny ['t-iz-i', 'ny']
# tipoff ['t-iz-ip', 'off']
# tipper ['t-iz-ip', 'per']
# tippet ['t-iz-ip', 'pet']
# tipping ['t-iz-ip', 'ping']
# tipple ['t-iz-ip', 'ple']
# tippy ['t-iz-ip', 'py']
# tipster ['t-iz-ip', 'ster']
# tipsy ['t-iz-ip', 'sy']
# tiptoe ['t-iz-ip', 'toe']
# tiptoed ['t-iz-ip', 'toed']
# tirade ['ti', 'r-iz-ade']
# tiring ['t-iz-ir', 'ing']
# tiros ['t-iz-i', 'ros']
# tissue ['t-iz-is', 'sue']
# tissues ['t-iz-is', 'sues']
# titan ['T-iz-i', 'tan']
# tithing ['t-iz-ith', 'ing']
# titian ['T-iz-i', 'tian']
# title ['t-iz-i', 'tle']
# titled ['t-iz-i', 'tled']
# titman ['t-iz-it', 'man']
# tito ['T-iz-i', 'to']
# titter ['t-iz-it', 'ter']
# tittle ['t-iz-it', 'tle']
# titus ['T-iz-i', 'tus']
# tizzy ['t-iz-iz', 'zy']
# tlingit ['Tl-iz-in', 'git']
# toaster ['t-iz-oast', 'er']
# toasting ['t-iz-oast', 'ing']
# tobey ['T-iz-o', 'bey']
# tobie ['t-iz-o', 'bie']
# toby ['T-iz-o', 'by']
# tocqueville ['T-iz-ocque', 'ville']
# today ['to', 'd-iz-ay']
# todays ['to', 'd-iz-ays']
# toddle ['t-iz-od', 'dle']
# toddler ['t-iz-od', 'dler']
# toddling ['t-iz-od', 'dling']
# toehold ['t-iz-oe', 'hold']
# toeing ['t-iz-oe', 'ing']
# toenail ['t-iz-oe', 'nail']
# toffee ['t-iz-of', 'fee']
# tofu ['t-iz-o', 'fu']
# toga ['t-iz-o', 'ga']
# toggle ['t-iz-og', 'gle']
# toggled ['t-iz-og', 'gled']
# toggling ['t-iz-og', 'gling']
# togo ['T-iz-o', 'go']
# toilet ['t-iz-oi', 'let']
# token ['t-iz-o', 'ken']
# tolan ['t-iz-o', 'lan']
# tollbooth ['t-iz-oll', 'booth']
# toller ['T-iz-ol', 'ler']
# tolly ['t-iz-ol', 'ly']
# tolstoy ['T-iz-ol', 'stoy']
# toman ['t-iz-o', 'man']
# tomblike ['t-iz-omb', 'like']
# tomboy ['t-iz-om', 'boy']
# tombstone ['t-iz-omb', 'stone']
# tomcat ['t-iz-om', 'cat']
# tommie ['T-iz-om', 'mie']
# tommy ['T-iz-om', 'my']
# tonal ['t-iz-on', 'al']
# toner ['t-iz-on', 'er']
# tonic ['t-iz-on', 'ic']
# tonight ['to', 'n-iz-ight']
# toning ['t-iz-on', 'ing']
# tonite ['ton', '-iz-ite']
# tonnage ['t-iz-on', 'nage']
# tonner ['t-iz-on', 'ner']
# tony ['t-iz-on', 'y']
# toolbox ['t-iz-ool', 'box']
# tooling ['t-iz-ool', 'ing']
# toothbrush ['t-iz-ooth', 'brush']
# toothless ['t-iz-ooth', 'less']
# toothlike ['t-iz-ooth', 'like']
# toothpaste ['t-iz-ooth', 'paste']
# toothpick ['t-iz-ooth', 'pick']
# toothy ['t-iz-ooth', 'y']
# tootle ['t-iz-oo', 'tle']
# tootsie ['t-iz-oot', 'sie']
# tootsie ['t-iz-oot', 's-iz-ie']
# topaz ['t-iz-o', 'paz']
# topic ['t-iz-op', 'ic']
# topknot ['t-iz-op', 'knot']
# topless ['t-iz-op', 'less']
# topper ['t-iz-op', 'per']
# topping ['t-iz-op', 'ping']
# topple ['t-iz-op', 'ple']
# toppled ['t-iz-op', 'pled']
# topples ['t-iz-op', 'ples']
# topsoil ['t-iz-op', 'soil']
# torah ['T-iz-o', 'rah']
# toran ['to', 'r-iz-an']
# torching ['t-iz-orch', 'ing']
# tori ['t-iz-o', 'ri']
# tories ['T-iz-o', 'ries']
# torment ['t-iz-or', 'ment']
# toro ['t-iz-o', 'ro']
# torpid ['t-iz-or', 'pid']
# torpor ['t-iz-or', 'por']
# torrent ['t-iz-or', 'rent']
# torres ['T-iz-or', 'res']
# torrid ['t-iz-or', 'rid']
# torso ['t-iz-or', 'so']
# torsos ['t-iz-or', 'sos']
# tortoise ['t-iz-or', 'toise']
# torture ['t-iz-or', 'ture']
# tortured ['t-iz-or', 'tured']
# tory ['T-iz-o', 'ry']
# tossing ['t-iz-oss', 'ing']
# tosto ['t-iz-os', 'to']
# tota ['t-iz-o', 'ta']
# total ['t-iz-o', 'tal']
# totaled ['t-iz-o', 'taled']
# totalled ['t-iz-o', 'talled']
# toted ['t-iz-ot', 'ed']
# totem ['t-iz-o', 'tem']
# toting ['t-iz-ot', 'ing']
# totter ['t-iz-ot', 'ter']
# totty ['t-iz-ot', 'ty']
# touchdown ['t-iz-ouch', 'down']
# touching ['t-iz-ouch', 'ing']
# touchstone ['t-iz-ouch', 'stone']
# touchy ['t-iz-ouch', 'y']
# toughen ['t-iz-ough', 'en']
# tougher ['t-iz-ough', 'er']
# toughest ['t-iz-ough', 'est']
# toughness ['t-iz-ough', 'ness']
# toulouse ['Tou', 'l-iz-ouse']
# toupee ['tou', 'p-iz-ee']
# tourist ['t-iz-our', 'ist']
# tourney ['t-iz-our', 'ney']
# tourneys ['t-iz-our', 'neys']
# toward ['to', 'w-iz-ard']
# towards ['to', 'w-iz-ards']
# towboat ['t-iz-ow', 'boat']
# towel ['t-iz-ow', 'el']
# tower ['t-iz-ow', 'er']
# towered ['t-iz-ow', 'ered']
# towner ['t-iz-own', 'er']
# townhouse ['t-iz-own', 'house']
# townie ['t-iz-own', 'ie']
# townsend ['T-iz-own', 'send']
# townsfolk ['t-iz-owns', 'folk']
# townshend ['T-iz-own', 'shend']
# township ['t-iz-own', 'ship']
# townsman ['t-iz-owns', 'man']
# towson ['T-iz-ow', 'son']
# toxic ['t-iz-ox', 'ic']
# toxin ['t-iz-ox', 'in']
# tracer ['tr-iz-ac', 'er']
# traces ['tr-iz-a', 'ces']
# tracing ['tr-iz-ac', 'ing']
# trackage ['tr-iz-ack', 'age']
# trackball ['tr-iz-ack', 'ball']
# tracker ['tr-iz-ack', 'er']
# tracking ['tr-iz-ack', 'ing']
# traction ['tr-iz-ac', 'tion']
# tractor ['tr-iz-ac', 'tor']
# tracy ['Tr-iz-a', 'cy']
# traded ['tr-iz-ad', 'ed']
# trademark ['tr-iz-ade', 'mark']
# tradeoff ['tr-iz-ade', 'off']
# trader ['tr-iz-ad', 'er']
# tradesmen ['tr-iz-ades', 'men']
# trading ['tr-iz-ad', 'ing']
# traffic ['tr-iz-af', 'fic']
# tragic ['tr-iz-ag', 'ic']
# trailer ['tr-iz-ail', 'er']
# trailhead ['tr-iz-ail', 'head']
# trailing ['tr-iz-ail', 'ing']
# trainee ['tr-iz-ain', 'ee']
# trainee ['tr-iz-ain', '-iz-ee']
# trainees ['tr-iz-ain', 'ees']
# trainees ['tr-iz-ain', '-iz-ees']
# trainer ['tr-iz-ain', 'er']
# training ['tr-iz-ain', 'ing']
# trainmen ['tr-iz-ain', 'men']
# traipsing ['tr-iz-aips', 'ing']
# traitor ['tr-iz-ai', 'tor']
# trajan ['Tr-iz-a', 'jan']
# tramble ['tr-iz-am', 'ble']
# trammel ['tr-iz-am', 'mel']
# tramping ['tr-iz-amp', 'ing']
# trample ['tr-iz-am', 'ple']
# trampled ['tr-iz-am', 'pled']
# trampling ['tr-iz-am', 'pling']
# tranquil ['tr-iz-an', 'quil']
# transact ['trans', '-iz-act']
# transcend ['tran', 'sc-iz-end']
# transcribe ['tran', 'scr-iz-ibe']
# transcribed ['tran', 'scr-iz-ibed']
# transcript ['tr-iz-an', 'script']
# transect ['tr-iz-an', 'sect']
# transfer ['trans', 'f-iz-er']
# transferred ['trans', 'f-iz-erred']
# transfix ['trans', 'f-iz-ix']
# transfixed ['trans', 'f-iz-ixed']
# transform ['trans', 'f-iz-orm']
# transfuse ['trans', 'f-iz-use']
# transfused ['trans', 'f-iz-used']
# transgress ['trans', 'gr-iz-ess']
# transient ['tr-iz-an', 'sient']
# transit ['tr-iz-an', 'sit']
# translate ['trans', 'l-iz-ate']
# transmit ['trans', 'm-iz-it']
# transom ['tr-iz-an', 'som']
# transplant ['trans', 'pl-iz-ant']
# transport ['trans', 'p-iz-ort']
# transpose ['trans', 'p-iz-ose']
# transposed ['trans', 'p-iz-osed']
# transvaal ['Trans', 'v-iz-aal']
# transverse ['trans', 'v-iz-erse']
# tranter ['tr-iz-ant', 'er']
# trapeze ['tra', 'p-iz-eze']
# trapping ['tr-iz-ap', 'ping']
# trappings ['tr-iz-ap', 'pings']
# trappist ['Tr-iz-ap', 'pist']
# trashy ['tr-iz-ash', 'y']
# trauma ['tr-iz-au', 'ma']
# traumas ['tr-iz-au', 'mas']
# travail ['tra', 'v-iz-ail']
# travel ['tr-iz-av', 'el']
# traveled ['tr-iz-av', 'eled']
# travelled ['tr-iz-av', 'elled']
# travers ['Tr-iz-av', 'ers']
# traverse ['tr-iz-av', 'erse']
# traversed ['tr-iz-av', 'ersed']
# travis ['Tr-iz-av', 'is']
# trawler ['tr-iz-awl', 'er']
# treading ['tr-iz-ead', 'ing']
# treadmill ['tr-iz-ead', 'mill']
# treadwheel ['tr-iz-ead', 'wheel']
# treason ['tr-iz-ea', 'son']
# treasure ['tr-iz-eas', 'ure']
# treasured ['tr-iz-eas', 'ured']
# treasures ['tr-iz-eas', 'ures']
# treater ['tr-iz-eat', 'er']
# treaties ['tr-iz-ea', 'ties']
# treatise ['tr-iz-ea', 'tise']
# treatment ['tr-iz-eat', 'ment']
# treaty ['tr-iz-ea', 'ty']
# treble ['tr-iz-e', 'ble']
# trebled ['tr-iz-e', 'bled']
# tredway ['tr-iz-ed', 'way']
# treeless ['tr-iz-ee', 'less']
# treetop ['tr-iz-ee', 'top']
# trekking ['tr-iz-ek', 'king']
# trellis ['tr-iz-el', 'lis']
# tremble ['tr-iz-em', 'ble']
# trembled ['tr-iz-em', 'bled']
# trembly ['tr-iz-em', 'bly']
# tremor ['tr-iz-em', 'or']
# trenchant ['tr-iz-ench', 'ant']
# trencher ['tr-iz-ench', 'er']
# trendy ['tr-iz-end', 'y']
# trenton ['Tr-iz-en', 'ton']
# trespass ['tr-iz-es', 'pass']
# tressel ['tr-iz-es', 'sel']
# trestle ['tr-iz-es', 'tle']
# trevor ['Tr-iz-ev', 'or']
# triad ['tr-iz-i', 'ad']
# triage ['tr-iz-i', 'age']
# trial ['tr-iz-i', 'al']
# tribal ['tr-iz-ib', 'al']
# tribble ['tr-iz-ib', 'ble']
# tribesman ['tr-iz-ibes', 'man']
# tribesmen ['tr-iz-ibes', 'men']
# tribune ['tr-iz-ib', 'une']
# tribute ['tr-iz-ib', 'ute']
# triceps ['tr-iz-i', 'ceps']
# tricking ['tr-iz-ick', 'ing']
# trickle ['tr-iz-ick', 'le']
# trickled ['tr-iz-ick', 'led']
# trickling ['tr-iz-ick', 'ling']
# trickster ['tr-iz-ick', 'ster']
# tricky ['tr-iz-ick', 'y']
# trident ['tr-iz-i', 'dent']
# trier ['tr-iz-i', 'er']
# trifle ['tr-iz-i', 'fle']
# trifling ['tr-iz-i', 'fling']
# trigger ['tr-iz-ig', 'ger']
# trilby ['tr-iz-il', 'by']
# trilling ['tr-iz-il', 'ling']
# trillion ['tr-iz-il', 'lion']
# trillions ['tr-iz-il', 'lions']
# trillo ['tr-iz-il', 'lo']
# trimble ['Tr-iz-im', 'ble']
# trimmer ['tr-iz-im', 'mer']
# trimming ['tr-iz-im', 'ming']
# trinket ['tr-iz-in', 'ket']
# trinkle ['tr-iz-in', 'kle']
# trio ['tr-iz-i', 'o']
# triple ['tr-iz-i', 'ple']
# tripled ['tr-iz-i', 'pled']
# triplet ['tr-iz-i', 'plet']
# tripod ['tr-iz-i', 'pod']
# tripper ['tr-iz-ip', 'per']
# tripping ['tr-iz-ip', 'ping']
# triptych ['tr-iz-ip', 'tych']
# tristan ['Tr-iz-is', 'tan']
# tristate ['tr-iz-i', 'state']
# tristram ['Tr-iz-is', 'tram']
# triton ['Tr-iz-i', 'ton']
# triumph ['tr-iz-i', 'umph']
# trivette ['triv', '-iz-ette']
# trixie ['Tr-iz-ix', 'ie']
# troika ['tr-iz-oi', 'ka']
# trojan ['Tr-iz-o', 'jan']
# trolley ['tr-iz-ol', 'ley']
# trolleys ['tr-iz-ol', 'leys']
# trombone ['trom', 'b-iz-one']
# trooper ['tr-iz-oop', 'er']
# trophies ['tr-iz-o', 'phies']
# trophy ['tr-iz-o', 'phy']
# tropic ['tr-iz-op', 'ic']
# trotsky ['Tr-iz-ot', 'sky']
# trotted ['tr-iz-ot', 'ted']
# trotter ['tr-iz-ot', 'ter']
# trotting ['tr-iz-ot', 'ting']
# trouble ['tr-iz-ou', 'ble']
# troubled ['tr-iz-ou', 'bled']
# trouncing ['tr-iz-ounc', 'ing']
# trouser ['tr-iz-ou', 'ser']
# trousers ['tr-iz-ou', 'sers']
# trowel ['tr-iz-ow', 'el']
# truant ['tr-iz-u', 'ant']
# trucker ['tr-iz-uck', 'er']
# trucking ['tr-iz-uck', 'ing']
# truckload ['tr-iz-uck', 'load']
# trudgen ['tr-iz-udg', 'en']
# trudging ['tr-iz-udg', 'ing']
# truelove ['tr-iz-ue', 'love']
# truer ['tr-iz-u', 'er']
# truest ['tr-iz-u', 'est']
# truffaut ['Truf', 'f-iz-aut']
# truffle ['tr-iz-uf', 'fle']
# truly ['tr-iz-u', 'ly']
# truman ['Tr-iz-u', 'man']
# trumbo ['Tr-iz-um', 'bo']
# trumbull ['Tr-iz-um', 'bull']
# trumpet ['tr-iz-um', 'pet']
# trumpets ['tr-iz-um', 'pets']
# truncate ['tr-iz-un', 'cate']
# truncheon ['tr-iz-un', 'cheon']
# trundle ['tr-iz-un', 'dle']
# trundled ['tr-iz-un', 'dled']
# truro ['Tr-iz-u', 'ro']
# trusted ['tr-iz-ust', 'ed']
# trustee ['trust', '-iz-ee']
# trusting ['tr-iz-ust', 'ing']
# trusty ['tr-iz-ust', 'y']
# truthful ['tr-iz-uth', 'ful']
# trying ['tr-iz-y', 'ing']
# tryout ['tr-iz-y', 'out']
# tsetse ['ts-iz-et', 'se']
# tuba ['t-iz-u', 'ba']
# tubal ['t-iz-ub', 'al']
# tubby ['t-iz-ub', 'by']
# tubing ['t-iz-ub', 'ing']
# tubman ['T-iz-ub', 'man']
# tubule ['t-iz-u', 'bule']
# tuchman ['T-iz-uch', 'man']
# tucker ['t-iz-uck', 'er']
# tucson ['T-iz-uc', 'son']
# tudor ['T-iz-u', 'dor']
# tuesday ['T-iz-ues', 'day']
# tuesdays ['T-iz-ues', 'days']
# tufa ['t-iz-u', 'fa']
# tufted ['t-iz-uft', 'ed']
# tugboat ['t-iz-ug', 'boat']
# tugging ['t-iz-ug', 'ging']
# tulip ['t-iz-u', 'lip']
# tully ['T-iz-ul', 'ly']
# tulsa ['T-iz-ul', 'sa']
# tumble ['t-iz-um', 'ble']
# tumbled ['t-iz-um', 'bled']
# tumbler ['t-iz-um', 'bler']
# tummies ['t-iz-um', 'mies']
# tummy ['t-iz-um', 'my']
# tumor ['t-iz-u', 'mor']
# tumult ['t-iz-u', 'mult']
# tuna ['t-iz-u', 'na']
# tunas ['t-iz-u', 'nas']
# tundra ['t-iz-un', 'dra']
# tuneful ['t-iz-une', 'ful']
# tuner ['t-iz-un', 'er']
# tuneup ['t-iz-une', 'up']
# tungsten ['t-iz-ung', 'sten']
# tunic ['t-iz-u', 'nic']
# tuning ['t-iz-un', 'ing']
# tunis ['T-iz-u', 'nis']
# tunnel ['t-iz-un', 'nel']
# tunney ['T-iz-un', 'ney']
# tunny ['t-iz-un', 'ny']
# turban ['t-iz-ur', 'ban']
# turbine ['t-iz-ur', 'bine']
# turbo ['t-iz-ur', 'bo']
# turbos ['t-iz-ur', 'bos']
# turbot ['tur', 'b-iz-ot']
# turgid ['t-iz-ur', 'gid']
# turin ['T-iz-u', 'rin']
# turing ['T-iz-u', 'ring']
# turkey ['T-iz-ur', 'key']
# turkeys ['t-iz-ur', 'keys']
# turkic ['T-iz-ur', 'kic']
# turkish ['T-iz-urk', 'ish']
# turkmen ['T-iz-urk', 'men']
# turko ['t-iz-urk', 'o']
# turmoil ['t-iz-ur', 'moil']
# turncoat ['t-iz-urn', 'coat']
# turndown ['t-iz-urn', 'down']
# turner ['t-iz-urn', 'er']
# turney ['t-iz-ur', 'ney']
# turning ['t-iz-urn', 'ing']
# turnip ['t-iz-ur', 'nip']
# turnkey ['t-iz-urn', 'key']
# turnoff ['t-iz-urn', 'off']
# turnout ['t-iz-urn', 'out']
# turnpike ['t-iz-urn', 'pike']
# turnstile ['t-iz-urn', 'stile']
# turpin ['T-iz-ur', 'pin']
# turquoise ['t-iz-ur', 'quoise']
# turret ['t-iz-ur', 'ret']
# turtle ['t-iz-ur', 'tle']
# turtles ['t-iz-ur', 'tles']
# tuscan ['T-iz-us', 'can']
# tussle ['t-iz-us', 'sle']
# tussled ['t-iz-us', 'sled']
# tutor ['t-iz-u', 'tor']
# tutti ['t-iz-ut', 'ti']
# tutu ['t-iz-u', 'tu']
# tv [None, 'V']
# tv [None, None]
# twaddell ['twad', 'd-iz-ell']
# twaddle ['tw-iz-ad', 'dle']
# twangy ['tw-iz-ang', 'y']
# tweedle ['tw-iz-ee', 'dle']
# tweedy ['tw-iz-eed', 'y']
# tweezer ['tw-iz-eez', 'er']
# tweezers ['tw-iz-eez', 'ers']
# twenties ['tw-iz-en', 'ties']
# twenty ['tw-iz-en', 'ty']
# twiddle ['tw-iz-id', 'dle']
# twiddling ['tw-iz-id', 'dling']
# twiggy ['tw-iz-ig', 'gy']
# twilight ['tw-iz-i', 'light']
# twining ['tw-iz-in', 'ing']
# twinjet ['tw-iz-in', 'jet']
# twinkle ['tw-iz-in', 'kle']
# twirler ['tw-iz-irl', 'er']
# twisted ['tw-iz-ist', 'ed']
# twister ['tw-iz-ist', 'er']
# twisting ['tw-iz-ist', 'ing']
# twisty ['tw-iz-ist', 'y']
# twitching ['tw-iz-itch', 'ing']
# twofold ['tw-iz-o', 'fold']
# twofold ['tw-iz-o', 'f-iz-old']
# twosome ['tw-iz-o', 'some']
# twyla ['Tw-iz-y', 'la']
# tycoon ['ty', 'c-iz-oon']
# tyger ['t-iz-y', 'ger']
# tying ['t-iz-y', 'ing']
# tyler ['T-iz-y', 'ler']
# tyndall ['T-iz-yn', 'dall']
# typecast ['t-iz-ype', 'cast']
# typeface ['t-iz-ype', 'face']
# typeset ['t-iz-ype', 'set']
# typhoid ['t-iz-y', 'phoid']
# typhoon ['ty', 'ph-iz-oon']
# typhus ['t-iz-y', 'phus']
# typing ['t-iz-yp', 'ing']
# typist ['t-iz-yp', 'ist']
# typo ['t-iz-y', 'po']
# tyrant ['t-iz-y', 'rant']
# tyson ['T-iz-y', 'son']
# uber [None, 'ber']
# ugly ['-iz-ug', 'ly']
# ugric [None, 'gric']
# uh-huh ['-iz-uh', 'huh']
# uh-huh ['-iz-uh', 'h-iz-uh']
# uhland [None, 'land']
# ukase ['-iz-u', 'kase']
# ukraine ['U', 'kr-iz-aine']
# ulcer ['-iz-ul', 'cer']
# ulfred [None, 'fred']
# ulmus ['-iz-ul', 'mus']
# ulrich [None, 'rich']
# ulster [None, 'ster']
# ultra ['-iz-ul', 'tra']
# ulva ['-iz-ul', 'va']
# umbel ['-iz-um', 'bel']
# umbra ['-iz-um', 'bra']
# umbrage ['-iz-um', 'brage']
# umpteen ['-iz-ump', 'teen']
# umpteen ['-iz-ump', 't-iz-een']
# umpteenth ['-iz-ump', 'teenth']
# unarm ['un', '-iz-arm']
# unarmed ['un', '-iz-armed']
# unbend ['un', 'b-iz-end']
# unbolt ['-iz-un', 'bolt']
# unborn ['-iz-un', 'born']
# unborn ['-iz-un', 'b-iz-orn']
# unbound ['un', 'b-iz-ound']
# unbowed ['un', 'b-iz-owed']
# unbuilt ['un', 'b-iz-uilt']
# unburned ['un', 'b-iz-urned']
# uncalled ['un', 'c-iz-alled']
# unchanged ['un', 'ch-iz-anged']
# unchecked ['un', 'ch-iz-ecked']
# unclaimed ['un', 'cl-iz-aimed']
# unclamp ['un', 'cl-iz-amp']
# uncle ['-iz-un', 'cle']
# unclean ['un', 'cl-iz-ean']
# unclear ['un', 'cl-iz-ear']
# uncles ['-iz-un', 'cles']
# uncoil ['un', 'c-iz-oil']
# uncoiled ['un', 'c-iz-oiled']
# uncool ['un', 'c-iz-ool']
# uncork ['un', 'c-iz-ork']
# uncouth ['-iz-un', 'couth']
# uncouth ['-iz-un', 'c-iz-outh']
# uncured ['un', 'c-iz-ured']
# uncut ['un', 'c-iz-ut']
# under ['-iz-un', 'der']
# undid ['un', 'd-iz-id']
# undine ['-iz-un', 'dine']
# undo ['un', 'd-iz-o']
# undock ['un', 'd-iz-ock']
# undone ['un', 'd-iz-one']
# undreamed ['un', 'dr-iz-eamed']
# undress ['un', 'dr-iz-ess']
# undressed ['un', 'dr-iz-essed']
# undue ['un', 'd-iz-ue']
# unearned ['un', '-iz-earned']
# unearth ['un', '-iz-earth']
# unease ['un', '-iz-ease']
# unfair ['un', 'f-iz-air']
# unfazed ['un', 'f-iz-azed']
# unfenced ['un', 'f-iz-enced']
# unfilled ['un', 'f-iz-illed']
# unfit ['un', 'f-iz-it']
# unfold ['un', 'f-iz-old']
# unformed ['un', 'f-iz-ormed']
# unfurl ['un', 'f-iz-url']
# unfurled ['un', 'f-iz-urled']
# unglue ['un', 'gl-iz-ue']
# unglued ['un', 'gl-iz-ued']
# unharmed ['un', 'h-iz-armed']
# unheard ['un', 'h-iz-eard']
# unhedged ['un', 'h-iz-edged']
# unhinge ['un', 'h-iz-inge']
# unhinged ['un', 'h-iz-inged']
# unhitch ['un', 'h-iz-itch']
# unhook ['un', 'h-iz-ook']
# unhorsed ['un', 'h-iz-orsed']
# unhurt ['un', 'h-iz-urt']
# uni ['-iz-u', 'ni']
# union ['-iz-un', 'ion']
# unique ['u', 'n-iz-ique']
# unit ['-iz-u', 'nit']
# unite ['-iz-u', 'nite']
# unix [None, 'nix']
# unjust ['un', 'j-iz-ust']
# unkempt ['un', 'k-iz-empt']
# unkind ['un', 'k-iz-ind']
# unknown ['un', 'kn-iz-own']
# unland ['-iz-un', 'land']
# unleash ['un', 'l-iz-eash']
# unless ['un', 'l-iz-ess']
# unlike ['un', 'l-iz-ike']
# unload ['un', 'l-iz-oad']
# unlock ['un', 'l-iz-ock']
# unloved ['un', 'l-iz-oved']
# unmade ['un', 'm-iz-ade']
# unmanned ['un', 'm-iz-anned']
# unmarked ['un', 'm-iz-arked']
# unmask ['un', 'm-iz-ask']
# unmasked ['un', 'm-iz-asked']
# unmatched ['un', 'm-iz-atched']
# unmet ['un', 'm-iz-et']
# unmixed ['un', 'm-iz-ixed']
# unmoved ['un', 'm-iz-oved']
# unnamed ['un', 'n-iz-amed']
# unnerve ['un', 'n-iz-erve']
# unnerved ['un', 'n-iz-erved']
# unpack ['un', 'p-iz-ack']
# unpaid ['un', 'p-iz-aid']
# unplaced ['un', 'pl-iz-aced']
# unplanned ['un', 'pl-iz-anned']
# unplug ['un', 'pl-iz-ug']
# unplugged ['un', 'pl-iz-ugged']
# unproved ['un', 'pr-iz-oved']
# unquote ['-iz-un', 'quote']
# unquote ['-iz-un', 'q-iz-uote']
# unread ['un', 'r-iz-ead']
# unrein ['-iz-un', 'rein']
# unrest ['un', 'r-iz-est']
# unsafe ['un', 's-iz-afe']
# unsaid ['un', 's-iz-aid']
# unscathed ['un', 'sc-iz-athed']
# unseal ['un', 's-iz-eal']
# unsealed ['un', 's-iz-ealed']
# unseat ['un', 's-iz-eat']
# unseen ['un', 's-iz-een']
# unsell ['un', 's-iz-ell']
# unser [None, 'ser']
# unset ['un', 's-iz-et']
# unsigned ['un', 's-iz-igned']
# unskilled ['un', 'sk-iz-illed']
# unsold ['un', 's-iz-old']
# unsolved ['un', 's-iz-olved']
# unsound ['un', 's-iz-ound']
# unspent ['un', 'sp-iz-ent']
# unspoiled ['un', 'sp-iz-oiled']
# unstained ['un', 'st-iz-ained']
# unstuck ['un', 'st-iz-uck']
# unsung ['un', 's-iz-ung']
# unsure ['un', 's-iz-ure']
# unswayed ['un', 'sw-iz-ayed']
# untie ['un', 't-iz-ie']
# untied ['un', 't-iz-ied']
# until ['un', 't-iz-il']
# unto ['-iz-un', 'to']
# untold ['un', 't-iz-old']
# untouched ['un', 't-iz-ouched']
# untrained ['un', 'tr-iz-ained']
# untried ['un', 'tr-iz-ied']
# untrue ['un', 'tr-iz-ue']
# untruth ['un', 'tr-iz-uth']
# untruths ['un', 'tr-iz-uths']
# unturned ['un', 't-iz-urned']
# unused ['un', '-iz-used']
# unveil ['un', 'v-iz-eil']
# unveiled ['un', 'v-iz-eiled']
# unwashed ['un', 'w-iz-ashed']
# unwed ['un', 'w-iz-ed']
# unwind ['un', 'w-iz-ind']
# unwise ['un', 'w-iz-ise']
# unwound ['un', 'w-iz-ound']
# unwrap ['un', 'wr-iz-ap']
# unwrapped ['un', 'wr-iz-apped']
# unzip ['un', 'z-iz-ip']
# unzipped ['un', 'z-iz-ipped']
# upbeat ['-iz-up', 'beat']
# upbraid ['-iz-up', 'braid']
# update ['up', 'd-iz-ate']
# updike [None, 'dike']
# updraft ['-iz-up', 'draft']
# upfront ['-iz-up', 'front']
# upgrade ['up', 'gr-iz-ade']
# upheld ['up', 'h-iz-eld']
# uphill ['-iz-up', 'hill']
# uphill ['-iz-up', 'h-iz-ill']
# uphold ['up', 'h-iz-old']
# upjohn ['-iz-up', 'john']
# upkeep ['-iz-up', 'keep']
# upland ['-iz-up', 'land']
# uplift ['-iz-up', 'lift']
# upon ['up', '-iz-on']
# upper ['-iz-up', 'per']
# upping ['-iz-up', 'ping']
# upright ['up', 'r-iz-ight']
# uprise ['-iz-up', 'rise']
# uproar ['-iz-up', 'roar']
# uproot ['up', 'r-iz-oot']
# upscale ['-iz-up', 'scale']
# upset ['up', 's-iz-et']
# upshot ['-iz-up', 'shot']
# upside ['-iz-up', 'side']
# upside ['-iz-up', 's-iz-ide']
# upstage ['up', 'st-iz-age']
# upstaged ['-iz-up', 'staged']
# upstaged ['-iz-up', 'st-iz-aged']
# upstairs ['up', 'st-iz-airs']
# upstart ['-iz-up', 'start']
# upstarts ['up', 'st-iz-arts']
# upstate ['-iz-up', 'state']
# upstate ['-iz-up', 'st-iz-ate']
# upstream ['-iz-up', 'stream']
# upstream ['-iz-up', 'str-iz-eam']
# upsurge ['-iz-up', 'surge']
# upswing ['up', 'sw-iz-ing']
# uptake ['-iz-up', 'take']
# uptick ['-iz-up', 'tick']
# uptight ['up', 't-iz-ight']
# upton [None, 'ton']
# uptown ['-iz-up', 'town']
# uptown ['-iz-up', 't-iz-own']
# uptrend ['-iz-up', 'trend']
# upturn ['up', 't-iz-urn']
# upward ['-iz-up', 'ward']
# upwards ['-iz-up', 'wards']
# ural [None, 'ral']
# urals [None, 'rals']
# urban ['-iz-ur', 'ban']
# urbane ['ur', 'b-iz-ane']
# urchin ['-iz-ur', 'chin']
# urdu ['Ur', 'd-iz-u']
# urey [None, 'rey']
# urgent ['-iz-ur', 'gent']
# urging ['-iz-urg', 'ing']
# uric ['-iz-u', 'ric']
# urine ['-iz-u', 'rine']
# ursa ['-iz-ur', 'sa']
# urson ['-iz-ur', 'son']
# ursus ['-iz-ur', 'sus']
# usage ['-iz-us', 'age']
# useful ['-iz-use', 'ful']
# useless ['-iz-use', 'less']
# user ['-iz-us', 'er']
# uses ['-iz-us', 'es']
# usher ['-iz-ush', 'er']
# using ['-iz-us', 'ing']
# usurp ['u', 's-iz-urp']
# utah [None, 'tah']
# uther [None, 'ther']
# utmost ['-iz-ut', 'most']
# utter ['-iz-ut', 'ter']
# uva [None, 'va']
# uzbek [None, 'bek']
# uzbeks [None, 'beks']
# uzi [None, 'zi']
# uzis [None, 'zis']
# vacant ['v-iz-a', 'cant']
# vacate ['v-iz-a', 'cate']
# vaccine ['vac', 'c-iz-ine']
# vaccines ['vac', 'c-iz-ines']
# vagrant ['v-iz-a', 'grant']
# vaguely ['v-iz-ague', 'ly']
# vagueness ['v-iz-ague', 'ness']
# vaguer ['v-iz-a', 'guer']
# vaguest ['v-iz-a', 'guest']
# vainly ['v-iz-ain', 'ly']
# valdez ['Val', 'd-iz-ez']
# valence ['v-iz-a', 'lence']
# valet ['val', '-iz-et']
# valiant ['v-iz-al', 'iant']
# valid ['v-iz-al', 'id']
# valley ['v-iz-al', 'ley']
# valleys ['v-iz-al', 'leys']
# valois ['Va', 'l-iz-ois']
# valor ['v-iz-al', 'or']
# value ['v-iz-al', 'ue']
# valued ['v-iz-al', 'ued']
# vampire ['v-iz-am', 'pire']
# vampires ['v-iz-am', 'pires']
# vandal ['v-iz-an', 'dal']
# vandyke ['Van', 'd-iz-yke']
# vanguard ['v-iz-an', 'guard']
# vanish ['v-iz-an', 'ish']
# vanished ['v-iz-an', 'ished']
# vanquish ['v-iz-an', 'quish']
# vantage ['v-iz-an', 'tage']
# vapid ['v-iz-ap', 'id']
# vapor ['v-iz-a', 'por']
# vara ['v-iz-a', 'ra']
# vargas ['V-iz-ar', 'gas']
# vari ['v-iz-a', 'ri']
# varied ['v-iz-ar', 'ied']
# varmint ['v-iz-ar', 'mint']
# varnish ['v-iz-ar', 'nish']
# varvel ['var', 'v-iz-el']
# vary ['v-iz-ar', 'y']
# vassal ['v-iz-as', 'sal']
# vastly ['v-iz-ast', 'ly']
# vastness ['v-iz-ast', 'ness']
# vatted ['v-iz-at', 'ted']
# vaudeville ['v-iz-aude', 'ville']
# vaulted ['v-iz-ault', 'ed']
# vaulting ['v-iz-ault', 'ing']
# vaunted ['v-iz-aunt', 'ed']
# vector ['v-iz-ec', 'tor']
# veda ['V-iz-e', 'da']
# vedette ['ve', 'd-iz-ette']
# veering ['v-iz-eer', 'ing']
# vega ['V-iz-e', 'ga']
# veggie ['v-iz-eg', 'gie']
# veiling ['v-iz-eil', 'ing']
# vela ['v-iz-e', 'la']
# velcro ['V-iz-el', 'cro']
# vella ['V-iz-el', 'la']
# velvet ['v-iz-el', 'vet']
# vena ['v-iz-e', 'na']
# venal ['v-iz-e', 'nal']
# vendee ['v-iz-end', 'ee']
# vendee ['v-iz-end', '-iz-ee']
# vendor ['v-iz-en', 'dor']
# veneer ['ve', 'n-iz-eer']
# veney ['v-iz-en', 'ey']
# vengeance ['v-iz-enge', 'ance']
# vengeful ['v-iz-enge', 'ful']
# venice ['V-iz-en', 'ice']
# venom ['v-iz-en', 'om']
# venous ['v-iz-e', 'nous']
# venter ['v-iz-en', 'ter']
# ventral ['v-iz-en', 'tral']
# venture ['v-iz-en', 'ture']
# ventured ['v-iz-en', 'tured']
# venue ['v-iz-en', 'ue']
# venus ['V-iz-e', 'nus']
# vera ['V-iz-e', 'ra']
# verbal ['v-iz-er', 'bal']
# verdant ['v-iz-er', 'dant']
# verdi ['V-iz-er', 'di']
# verdict ['v-iz-er', 'dict']
# verdin ['v-iz-er', 'din']
# verdun ['V-iz-er', 'dun']
# vergil ['V-iz-er', 'gil']
# verging ['v-iz-erg', 'ing']
# vermeer ['V-iz-er', 'meer']
# vermin ['v-iz-er', 'min']
# vermont ['Ver', 'm-iz-ont']
# vermouth ['ver', 'm-iz-outh']
# vernal ['v-iz-er', 'nal']
# verner ['V-iz-er', 'ner']
# versailles ['Ver', 's-iz-ailles']
# verser ['v-iz-ers', 'er']
# version ['v-iz-er', 'sion']
# versus ['v-iz-er', 'sus']
# vertex ['v-iz-er', 'tex']
# verwoerd ['Ver', 'w-iz-oerd']
# very ['v-iz-er', 'y']
# vesey ['V-iz-e', 'sey']
# vespa ['v-iz-es', 'pa']
# vesper ['v-iz-es', 'per']
# vessel ['v-iz-es', 'sel']
# vesta ['V-iz-es', 'ta']
# vestal ['v-iz-es', 'tal']
# vested ['v-iz-est', 'ed']
# vestige ['v-iz-es', 'tige']
# vesting ['v-iz-est', 'ing']
# veto ['v-iz-e', 'to']
# vetoed ['v-iz-e', 'toed']
# vetoes ['v-iz-e', 'toes']
# vetted ['v-iz-et', 'ted']
# vetting ['v-iz-et', 'ting']
# via ['v-iz-i', 'a']
# vial ['v-iz-i', 'al']
# vibrant ['v-iz-i', 'brant']
# vibrate ['v-iz-i', 'brate']
# vicar ['v-iz-ic', 'ar']
# viceroy ['v-iz-ice', 'roy']
# vices ['v-iz-ic', 'es']
# vichy ['V-iz-i', 'chy']
# vicious ['v-iz-i', 'cious']
# vicksburg ['V-iz-icks', 'burg']
# vicky ['V-iz-ick', 'y']
# victim ['v-iz-ic', 'tim']
# victor ['V-iz-ic', 'tor']
# vidal ['Vi', 'd-iz-al']
# viet ['Vi', '-iz-et']
# viewer ['v-iz-iew', 'er']
# viewing ['v-iz-iew', 'ing']
# viewpoint ['v-iz-iew', 'point']
# vigil ['v-iz-ig', 'il']
# vignette ['vi', 'gn-iz-ette']
# vigor ['v-iz-ig', 'or']
# viking ['V-iz-i', 'king']
# vila ['V-iz-i', 'la']
# villa ['v-iz-il', 'la']
# village ['v-iz-il', 'lage']
# villain ['v-iz-il', 'lain']
# villard ['V-iz-il', 'lard']
# villi ['v-iz-il', 'li']
# vinca ['v-iz-in', 'ca']
# vincent ['V-iz-in', 'cent']
# viner ['v-iz-in', 'er']
# vineyard ['v-iz-ine', 'yard']
# vinnie ['V-iz-in', 'nie']
# vinny ['V-iz-in', 'ny']
# vinson ['V-iz-in', 'son']
# vintage ['v-iz-in', 'tage']
# vintner ['v-iz-int', 'ner']
# vinyl ['v-iz-i', 'nyl']
# viole ['vi', '-iz-ole']
# viper ['v-iz-i', 'per']
# viral ['v-iz-i', 'ral']
# virga ['v-iz-ir', 'ga']
# virgil ['V-iz-ir', 'gil']
# virgin ['v-iz-ir', 'gin']
# virgo ['V-iz-ir', 'go']
# virile ['v-iz-ir', 'ile']
# virtue ['v-iz-ir', 'tue']
# virus ['v-iz-i', 'rus']
# visa ['v-iz-i', 'sa']
# visage ['v-iz-is', 'age']
# visas ['v-iz-i', 'sas']
# viscous ['v-iz-is', 'cous']
# vision ['v-iz-i', 'sion']
# visit ['v-iz-is', 'it']
# visor ['v-iz-i', 'sor']
# vista ['v-iz-is', 'ta']
# vital ['v-iz-i', 'tal']
# vitric ['v-iz-it', 'ric']
# viva ['v-iz-i', 'va']
# vivid ['v-iz-iv', 'id']
# vixen ['v-iz-ix', 'en']
# vocal ['v-iz-o', 'cal']
# vodka ['v-iz-od', 'ka']
# voiceless ['v-iz-oice', 'less']
# voicemail ['v-iz-oice', 'mail']
# voices ['v-iz-oic', 'es']
# voicing ['v-iz-oic', 'ing']
# voided ['v-iz-oid', 'ed']
# voiding ['v-iz-oid', 'ing']
# volga ['V-iz-ol', 'ga']
# volley ['v-iz-ol', 'ley']
# volleys ['v-iz-ol', 'leys']
# volta ['V-iz-ol', 'ta']
# voltage ['v-iz-olt', 'age']
# voltaire ['Vol', 't-iz-aire']
# volume ['v-iz-ol', 'ume']
# volvox ['v-iz-ol', 'vox']
# vomit ['v-iz-om', 'it']
# voodoo ['v-iz-oo', 'doo']
# vortex ['v-iz-or', 'tex']
# voted ['v-iz-ot', 'ed']
# voter ['v-iz-ot', 'er']
# voting ['v-iz-ot', 'ing']
# voucher ['v-iz-ouch', 'er']
# vouching ['v-iz-ouch', 'ing']
# vowel ['v-iz-ow', 'el']
# voyage ['v-iz-oy', 'age']
# voyaged ['v-iz-oy', 'aged']
# voyeur ['vo', '-iz-yeur']
# vulcan ['V-iz-ul', 'can']
# vulgar ['v-iz-ul', 'gar']
# vulture ['v-iz-ul', 'ture']
# vying ['v-iz-y', 'ing']
# wabash ['W-iz-a', 'bash']
# wacko ['w-iz-ack', 'o']
# wackos ['w-iz-ack', 'os']
# wacky ['w-iz-ack', 'y']
# waco ['W-iz-a', 'co']
# wadded ['w-iz-ad', 'ded']
# waddie ['w-iz-ad', 'die']
# waddle ['w-iz-ad', 'dle']
# waddy ['w-iz-ad', 'dy']
# waded ['w-iz-ad', 'ed']
# wader ['w-iz-ad', 'er']
# wading ['w-iz-ad', 'ing']
# wafer ['w-iz-a', 'fer']
# waffle ['w-iz-af', 'fle']
# waffled ['w-iz-af', 'fled']
# waffling ['w-iz-af', 'fling']
# wager ['w-iz-a', 'ger']
# wages ['w-iz-a', 'ges']
# wagging ['w-iz-ag', 'ging']
# waging ['w-iz-ag', 'ing']
# wagner ['W-iz-ag', 'ner']
# wagon ['w-iz-ag', 'on']
# wahoo ['wa', 'h-iz-oo']
# wainwright ['W-iz-ain', 'wright']
# waistline ['w-iz-aist', 'line']
# waiter ['w-iz-ait', 'er']
# waiting ['w-iz-ait', 'ing']
# waitress ['w-iz-ait', 'ress']
# waiver ['w-iz-aiv', 'er']
# waiving ['w-iz-aiv', 'ing']
# wajda ['W-iz-aj', 'da']
# wakefield ['W-iz-ake', 'field']
# waken ['w-iz-ak', 'en']
# waking ['w-iz-ak', 'ing']
# waldheim ['W-iz-ald', 'heim']
# waldo ['W-iz-al', 'do']
# walfred ['W-iz-al', 'fred']
# walker ['w-iz-alk', 'er']
# walking ['w-iz-alk', 'ing']
# walkman ['W-iz-alk', 'man']
# walkout ['w-iz-alk', 'out']
# walkway ['w-iz-alk', 'way']
# wallace ['W-iz-al', 'lace']
# wallack ['w-iz-al', 'lack']
# wallboard ['w-iz-all', 'board']
# waller ['w-iz-al', 'ler']
# wallet ['w-iz-al', 'let']
# walleye ['w-iz-all', 'eye']
# walling ['w-iz-all', 'ing']
# wallop ['w-iz-al', 'lop']
# wallow ['w-iz-al', 'low']
# wallsend ['W-iz-alls', 'end']
# wally ['w-iz-al', 'ly']
# walnut ['w-iz-al', 'nut']
# walpole ['W-iz-al', 'pole']
# walrus ['w-iz-al', 'rus']
# walter ['W-iz-al', 'ter']
# walters ['W-iz-al', 'ters']
# walther ['W-iz-al', 'ther']
# walton ['W-iz-al', 'ton']
# waltzer ['w-iz-altz', 'er']
# wamble ['w-iz-am', 'ble']
# wampum ['w-iz-am', 'pum']
# wanda ['W-iz-an', 'da']
# wander ['w-iz-an', 'der']
# wanger ['w-iz-ang', 'er']
# wangle ['w-iz-an', 'gle']
# wangled ['w-iz-an', 'gled']
# wangler ['w-iz-an', 'gler']
# waning ['w-iz-an', 'ing']
# wanner ['w-iz-an', 'ner']
# wantage ['w-iz-ant', 'age']
# wanting ['w-iz-ant', 'ing']
# wanton ['w-iz-an', 'ton']
# wapping ['w-iz-ap', 'ping']
# warbler ['w-iz-ar', 'bler']
# warburg ['W-iz-ar', 'burg']
# warded ['w-iz-ard', 'ed']
# warden ['w-iz-ar', 'den']
# warder ['w-iz-ard', 'er']
# wardrobe ['w-iz-ard', 'robe']
# warehouse ['w-iz-are', 'house']
# warehoused ['w-iz-are', 'housed']
# warfare ['w-iz-ar', 'fare']
# warhead ['w-iz-ar', 'head']
# warhol ['W-iz-ar', 'hol']
# waring ['w-iz-ar', 'ing']
# warlike ['w-iz-ar', 'like']
# warling ['w-iz-ar', 'ling']
# warlord ['w-iz-ar', 'lord']
# warmer ['w-iz-arm', 'er']
# warmest ['w-iz-arm', 'est']
# warming ['w-iz-arm', 'ing']
# warmish ['w-iz-arm', 'ish']
# warmly ['w-iz-arm', 'ly']
# warmup ['w-iz-arm', 'up']
# warner ['w-iz-arn', 'er']
# warning ['w-iz-arn', 'ing']
# warpath ['w-iz-ar', 'path']
# warping ['w-iz-arp', 'ing']
# warplane ['w-iz-ar', 'plane']
# warrant ['w-iz-ar', 'rant']
# warren ['W-iz-ar', 'ren']
# warring ['w-iz-ar', 'ring']
# warsaw ['W-iz-ar', 'saw']
# warship ['w-iz-ar', 'ship']
# wartime ['w-iz-ar', 'time']
# warwick ['W-iz-ar', 'wick']
# wary ['w-iz-ar', 'y']
# washboard ['w-iz-ash', 'board']
# washcloth ['w-iz-ash', 'cloth']
# washer ['w-iz-ash', 'er']
# washing ['w-iz-ash', 'ing']
# washout ['w-iz-ash', 'out']
# washroom ['w-iz-ash', 'room']
# washtub ['w-iz-ash', 'tub']
# washy ['w-iz-ash', 'y']
# wasted ['w-iz-ast', 'ed']
# wasteful ['w-iz-aste', 'ful']
# wasteland ['w-iz-aste', 'land']
# waster ['w-iz-ast', 'er']
# wasting ['w-iz-ast', 'ing']
# watchdog ['w-iz-atch', 'dog']
# watcher ['w-iz-atch', 'er']
# watches ['w-iz-atch', 'es']
# watchful ['w-iz-atch', 'ful']
# watching ['w-iz-atch', 'ing']
# watchman ['w-iz-atch', 'man']
# watchword ['w-iz-atch', 'word']
# water ['w-iz-a', 'ter']
# watered ['w-iz-a', 'tered']
# waters ['w-iz-a', 'ters']
# watford ['W-iz-at', 'ford']
# watson ['W-iz-at', 'son']
# wattage ['w-iz-att', 'age']
# wausau ['W-iz-au', 'sau']
# wavelength ['w-iz-ave', 'length']
# waver ['w-iz-a', 'ver']
# waving ['w-iz-av', 'ing']
# wavy ['w-iz-av', 'y']
# waxes ['w-iz-ax', 'es']
# waxing ['w-iz-ax', 'ing']
# waxy ['w-iz-ax', 'y']
# waylaid ['w-iz-ay', 'laid']
# wayland ['W-iz-ay', 'land']
# waylay ['w-iz-ay', 'lay']
# waylon ['W-iz-ay', 'lon']
# wayside ['w-iz-ay', 'side']
# wayward ['w-iz-ay', 'ward']
# weaken ['w-iz-eak', 'en']
# weaker ['w-iz-eak', 'er']
# weakest ['w-iz-eak', 'est']
# weakling ['w-iz-eak', 'ling']
# weakly ['w-iz-eak', 'ly']
# weakness ['w-iz-eak', 'ness']
# wealthy ['w-iz-ealth', 'y']
# weapon ['w-iz-eap', 'on']
# wearer ['w-iz-ear', 'er']
# wearied ['w-iz-ea', 'ried']
# wearing ['w-iz-ear', 'ing']
# weary ['w-iz-ea', 'ry']
# weasel ['w-iz-ea', 'sel']
# weather ['w-iz-eath', 'er']
# weathered ['w-iz-eath', 'ered']
# weathers ['w-iz-eath', 'ers']
# weaver ['w-iz-eav', 'er']
# weaving ['w-iz-eav', 'ing']
# webber ['w-iz-eb', 'ber']
# webbing ['w-iz-eb', 'bing']
# weber ['W-iz-e', 'ber']
# website ['w-iz-eb', 'site']
# webster ['W-iz-eb', 'ster']
# wedded ['w-iz-ed', 'ded']
# wedding ['w-iz-ed', 'ding']
# wedel ['w-iz-e', 'del']
# wedgwood ['W-iz-edg', 'wood']
# wedlock ['w-iz-ed', 'lock']
# wednesday ['W-iz-ednes', 'day']
# wednesdays ['W-iz-ednes', 'days']
# weeding ['w-iz-eed', 'ing']
# weedy ['w-iz-eed', 'y']
# weekday ['w-iz-eek', 'day']
# weekdays ['w-iz-eek', 'days']
# weekend ['w-iz-eek', 'end']
# weekends ['w-iz-eek', 'ends']
# weekly ['w-iz-eek', 'ly']
# weeny ['w-iz-ee', 'ny']
# weeping ['w-iz-eep', 'ing']
# weepy ['w-iz-eep', 'y']
# weevil ['w-iz-ee', 'vil']
# weighing ['w-iz-eigh', 'ing']
# weighted ['w-iz-eight', 'ed']
# weightless ['w-iz-eight', 'less']
# weighty ['w-iz-eight', 'y']
# weimar ['W-iz-ei', 'mar']
# weirdness ['w-iz-eird', 'ness']
# weirdo ['w-iz-eird', 'o']
# weismann ['W-iz-eis', 'mann']
# welby ['W-iz-el', 'by']
# welcher ['w-iz-elch', 'er']
# welcome ['w-iz-el', 'come']
# welcomed ['w-iz-el', 'comed']
# welder ['w-iz-eld', 'er']
# weldon ['W-iz-el', 'don']
# welfare ['w-iz-el', 'fare']
# wellborn ['w-iz-ell', 'born']
# wellborn ['w-iz-ell', 'b-iz-orn']
# weller ['W-iz-el', 'ler']
# wellhead ['w-iz-ell', 'head']
# wellness ['w-iz-ell', 'ness']
# wellpoint ['w-iz-ell', 'point']
# wellspring ['w-iz-ell', 'spring']
# welter ['w-iz-el', 'ter']
# welty ['W-iz-el', 'ty']
# wembley ['W-iz-em', 'bley']
# wendell ['W-iz-en', 'dell']
# wending ['w-iz-end', 'ing']
# wendy ['W-iz-en', 'dy']
# wentworth ['W-iz-ent', 'worth']
# wentworth ['W-iz-ent', 'w-iz-orth']
# wenzel ['W-iz-en', 'zel']
# werewolf ['w-iz-ere', 'wolf']
# wertheim ['W-iz-ert', 'heim']
# wesley ['W-iz-es', 'ley']
# wessex ['W-iz-es', 'sex']
# westbound ['w-iz-est', 'bound']
# wester ['w-iz-est', 'er']
# western ['w-iz-est', 'ern']
# westland ['W-iz-est', 'land']
# westling ['w-iz-est', 'ling']
# weston ['W-iz-es', 'ton']
# westward ['w-iz-est', 'ward']
# westwards ['w-iz-est', 'wards']
# wetland ['w-iz-et', 'land']
# wetness ['w-iz-et', 'ness']
# wetter ['w-iz-et', 'ter']
# wettest ['w-iz-et', 'test']
# wetting ['w-iz-et', 'ting']
# weymouth ['W-iz-ey', 'mouth']
# whacking ['wh-iz-ack', 'ing']
# whacko ['wh-iz-ack', 'o']
# whaler ['wh-iz-al', 'er']
# whaling ['wh-iz-al', 'ing']
# whammy ['wh-iz-am', 'my']
# wharton ['Wh-iz-ar', 'ton']
# whatnot ['wh-iz-at', 'not']
# wheaten ['wh-iz-eat', 'en']
# wheatley ['Wh-iz-eat', 'ley']
# wheelbase ['wh-iz-eel', 'base']
# wheelchair ['wh-iz-eel', 'chair']
# wheeler ['wh-iz-eel', 'er']
# wheeling ['wh-iz-eel', 'ing']
# wheelwright ['Wh-iz-eel', 'wright']
# wheezing ['wh-iz-eez', 'ing']
# whereas ['where', '-iz-as']
# whereby ['where', 'b-iz-y']
# wherein ['where', '-iz-in']
# wherry ['wh-iz-er', 'ry']
# whether ['wh-iz-eth', 'er']
# whetstone ['wh-iz-et', 'stone']
# whetted ['wh-iz-et', 'ted']
# whicker ['wh-iz-ick', 'er']
# whimper ['wh-iz-im', 'per']
# whimsy ['wh-iz-im', 'sy']
# whiner ['wh-iz-in', 'er']
# whining ['wh-iz-in', 'ing']
# whiny ['wh-iz-in', 'y']
# whiplash ['wh-iz-ip', 'lash']
# whipping ['wh-iz-ip', 'ping']
# whipsaw ['wh-iz-ip', 'saw']
# whipsawed ['wh-iz-ip', 'sawed']
# whirling ['wh-iz-irl', 'ing']
# whirlpool ['wh-iz-irl', 'pool']
# whirlwind ['wh-iz-irl', 'wind']
# whirring ['wh-iz-ir', 'ring']
# whisker ['wh-iz-isk', 'er']
# whiskey ['wh-iz-is', 'key']
# whiskeys ['wh-iz-is', 'keys']
# whisky ['wh-iz-is', 'ky']
# whisper ['wh-iz-is', 'per']
# whispered ['wh-iz-is', 'pered']
# whistle ['wh-iz-is', 'tle']
# whistled ['wh-iz-is', 'tled']
# whistler ['wh-iz-is', 'tler']
# whistling ['wh-iz-is', 'tling']
# whitebread ['wh-iz-ite', 'bread']
# whited ['wh-iz-it', 'ed']
# whitefield ['wh-iz-ite', 'field']
# whitefish ['wh-iz-ite', 'fish']
# whitehall ['Wh-iz-ite', 'hall']
# whitehead ['wh-iz-ite', 'head']
# whitehorse ['wh-iz-ite', 'horse']
# whitelaw ['Wh-iz-ite', 'law']
# whiteley ['wh-iz-ite', 'ley']
# whitely ['wh-iz-ite', 'ly']
# whiteman ['wh-iz-ite', 'man']
# whiten ['wh-iz-it', 'en']
# whiteness ['wh-iz-ite', 'ness']
# whiter ['wh-iz-it', 'er']
# whiteside ['wh-iz-ite', 'side']
# whitest ['wh-iz-it', 'est']
# whitestone ['wh-iz-ite', 'stone']
# whitetail ['wh-iz-ite', 'tail']
# whitewash ['wh-iz-ite', 'wash']
# whitewashed ['wh-iz-ite', 'washed']
# whitey ['wh-iz-ite', 'y']
# whither ['wh-iz-ith', 'er']
# whiting ['wh-iz-it', 'ing']
# whitings ['wh-iz-it', 'ings']
# whitish ['wh-iz-it', 'ish']
# whitling ['wh-iz-it', 'ling']
# whitlow ['wh-iz-it', 'low']
# whitman ['Wh-iz-it', 'man']
# whitney ['Wh-iz-it', 'ney']
# whitson ['wh-iz-it', 'son']
# whittle ['wh-iz-it', 'tle']
# whittled ['wh-iz-it', 'tled']
# whittling ['wh-iz-it', 'tling']
# whizzing ['wh-iz-iz', 'zing']
# wholeness ['wh-iz-ole', 'ness']
# wholesale ['wh-iz-ole', 'sale']
# wholesome ['wh-iz-ole', 'some']
# wholly ['wh-iz-ol', 'ly']
# whoopee ['wh-iz-oop', 'ee']
# whoopee ['wh-iz-oop', '-iz-ee']
# whoopie ['wh-iz-oop', 'ie']
# whooping ['wh-iz-oop', 'ing']
# whopper ['wh-iz-op', 'per']
# whopping ['wh-iz-op', 'ping']
# whorehouse ['wh-iz-ore', 'house']
# wicca ['w-iz-ic', 'ca']
# wicked ['w-iz-ick', 'ed']
# wicker ['w-iz-ick', 'er']
# wicket ['w-iz-ick', 'et']
# wickliffe ['W-iz-ick', 'liffe']
# widder ['w-iz-id', 'der']
# widely ['w-iz-ide', 'ly']
# widen ['w-iz-id', 'en']
# wider ['w-iz-id', 'er']
# widespread ['w-iz-ide', 'spread']
# widespread ['w-iz-ide', 'spr-iz-ead']
# widest ['w-iz-id', 'est']
# widget ['w-iz-idg', 'et']
# widow ['w-iz-id', 'ow']
# wieland ['W-iz-ie', 'land']
# wielding ['w-iz-ield', 'ing']
# wiener ['w-iz-ie', 'ner']
# wiesel ['W-iz-ie', 'sel']
# wiggle ['w-iz-ig', 'gle']
# wigmore ['W-iz-ig', 'more']
# wigwam ['w-iz-ig', 'wam']
# wilbur ['W-iz-il', 'bur']
# wildcat ['w-iz-ild', 'cat']
# wildcats ['w-iz-ild', 'cats']
# wilder ['w-iz-ild', 'er']
# wildest ['w-iz-ild', 'est']
# wilding ['w-iz-ild', 'ing']
# wildlife ['w-iz-ild', 'life']
# wildly ['w-iz-ild', 'ly']
# wildness ['w-iz-ild', 'ness']
# wildwood ['w-iz-ild', 'wood']
# wiley ['W-iz-i', 'ley']
# wilfred ['W-iz-il', 'fred']
# wilhelm ['W-iz-il', 'helm']
# wiling ['w-iz-il', 'ing']
# wilkie ['W-iz-il', 'kie']
# wilkins ['W-iz-il', 'kins']
# willa ['W-iz-il', 'la']
# willard ['W-iz-il', 'lard']
# willem ['W-iz-il', 'lem']
# willer ['w-iz-ill', 'er']
# willet ['w-iz-il', 'let']
# willets ['w-iz-il', 'lets']
# willette ['Will', '-iz-ette']
# willey ['w-iz-il', 'ley']
# willful ['w-iz-ill', 'ful']
# william ['W-iz-il', 'liam']
# williams ['W-iz-il', 'liams']
# willie ['W-iz-il', 'lie']
# willing ['w-iz-ill', 'ing']
# willkie ['w-iz-ill', 'kie']
# willock ['w-iz-il', 'lock']
# willow ['w-iz-il', 'low']
# willy ['W-iz-il', 'ly']
# willyard ['w-iz-ill', 'yard']
# wilma ['W-iz-il', 'ma']
# wilmer ['W-iz-il', 'mer']
# wilson ['W-iz-il', 'son']
# wilton ['W-iz-il', 'ton']
# wiltshire ['W-iz-ilt', 'shire']
# wily ['w-iz-il', 'y']
# wimpy ['w-iz-imp', 'y']
# wincing ['w-iz-inc', 'ing']
# winded ['w-iz-ind', 'ed']
# winder ['w-iz-ind', 'er']
# windfall ['w-iz-ind', 'fall']
# windhoek ['W-iz-ind', 'hoek']
# winding ['w-iz-ind', 'ing']
# windlass ['w-iz-ind', 'lass']
# windle ['w-iz-in', 'dle']
# windmill ['w-iz-ind', 'mill']
# window ['w-iz-in', 'dow']
# windowed ['w-iz-in', 'dowed']
# windows ['w-iz-in', 'dows']
# windshield ['w-iz-ind', 'shield']
# windsor ['W-iz-ind', 'sor']
# windstorm ['w-iz-ind', 'storm']
# windswept ['w-iz-ind', 'swept']
# windup ['w-iz-ind', 'up']
# windward ['w-iz-ind', 'ward']
# windy ['w-iz-ind', 'y']
# winey ['w-iz-ine', 'y']
# winfield ['W-iz-in', 'field']
# winfred ['W-iz-in', 'fred']
# wingback ['w-iz-ing', 'back']
# winger ['w-iz-ing', 'er']
# winglike ['w-iz-ing', 'like']
# wingman ['w-iz-ing', 'man']
# wingspan ['w-iz-ing', 'span']
# wining ['w-iz-in', 'ing']
# winker ['w-iz-ink', 'er']
# winkle ['w-iz-in', 'kle']
# winner ['w-iz-in', 'ner']
# winnie ['W-iz-in', 'nie']
# winning ['w-iz-in', 'ning']
# winnow ['w-iz-in', 'now']
# wino ['w-iz-in', 'o']
# winslow ['W-iz-ins', 'low']
# winsome ['w-iz-in', 'some']
# winston ['W-iz-in', 'ston']
# winter ['w-iz-in', 'ter']
# winters ['w-iz-in', 'ters']
# wintle ['w-iz-in', 'tle']
# wintry ['w-iz-in', 'try']
# wipeout ['w-iz-ipe', 'out']
# wiper ['w-iz-ip', 'er']
# wiping ['w-iz-ip', 'ing']
# wireless ['w-iz-ire', 'less']
# wireman ['w-iz-ire', 'man']
# wiring ['w-iz-ir', 'ing']
# wiry ['w-iz-ir', 'y']
# wisdom ['w-iz-is', 'dom']
# wisecrack ['w-iz-ise', 'crack']
# wisecracks ['w-iz-ise', 'cracks']
# wisely ['w-iz-ise', 'ly']
# wiseman ['w-iz-ise', 'man']
# wiser ['w-iz-is', 'er']
# wisest ['w-iz-is', 'est']
# wishbone ['w-iz-ish', 'bone']
# wisher ['w-iz-ish', 'er']
# wishful ['w-iz-ish', 'ful']
# wishing ['w-iz-ish', 'ing']
# wispy ['w-iz-isp', 'y']
# wistful ['w-iz-ist', 'ful']
# witchcraft ['w-iz-itch', 'craft']
# witcher ['w-iz-itch', 'er']
# witches ['w-iz-itch', 'es']
# witchhunt ['w-iz-itch', 'hunt']
# witching ['w-iz-itch', 'ing']
# witchy ['w-iz-itch', 'y']
# withdraw ['with', 'dr-iz-aw']
# withdrawn ['with', 'dr-iz-awn']
# withdrew ['with', 'dr-iz-ew']
# wither ['w-iz-ith', 'er']
# withered ['w-iz-ith', 'ered']
# withers ['w-iz-ith', 'ers']
# withheld ['with', 'h-iz-eld']
# withhold ['with', 'h-iz-old']
# within ['with', '-iz-in']
# without ['with', '-iz-out']
# withstand ['with', 'st-iz-and']
# withstood ['with', 'st-iz-ood']
# witless ['w-iz-it', 'less']
# witness ['w-iz-it', 'ness']
# witted ['w-iz-it', 'ted']
# witting ['w-iz-it', 'ting']
# witty ['w-iz-it', 'ty']
# wizard ['w-iz-iz', 'ard']
# wizen ['w-iz-iz', 'en']
# wizened ['w-iz-iz', 'ened']
# wobble ['w-iz-ob', 'ble']
# wobbled ['w-iz-ob', 'bled']
# woeful ['w-iz-oe', 'ful']
# woken ['w-iz-ok', 'en']
# wolcott ['W-iz-ol', 'cott']
# wolfgang ['W-iz-olf', 'gang']
# wolfman ['w-iz-olf', 'man']
# wolfram ['w-iz-olf', 'ram']
# wolsey ['W-iz-ol', 'sey']
# woman ['w-iz-om', 'an']
# wombat ['w-iz-om', 'bat']
# women ['w-iz-om', 'en']
# wonder ['w-iz-on', 'der']
# wondered ['w-iz-on', 'dered']
# wonders ['w-iz-on', 'ders']
# wondrous ['w-iz-on', 'drous']
# woodchip ['w-iz-ood', 'chip']
# woodchuck ['w-iz-ood', 'chuck']
# woodcock ['w-iz-ood', 'cock']
# wooded ['w-iz-ood', 'ed']
# wooden ['w-iz-ood', 'en']
# woodhouse ['w-iz-ood', 'house']
# woodhull ['W-iz-ood', 'hull']
# woodland ['w-iz-ood', 'land']
# woodman ['w-iz-ood', 'man']
# woodroof ['w-iz-ood', 'roof']
# woodrow ['W-iz-ood', 'row']
# woodruff ['W-iz-ood', 'ruff']
# woodshed ['w-iz-ood', 'shed']
# woodsman ['w-iz-oods', 'man']
# woodsmen ['w-iz-oods', 'men']
# woodson ['W-iz-ood', 'son']
# woodstock ['W-iz-ood', 'stock']
# woodward ['W-iz-ood', 'ward']
# woodwind ['w-iz-ood', 'wind']
# woodwork ['w-iz-ood', 'work']
# woody ['w-iz-ood', 'y']
# woolen ['w-iz-ool', 'en']
# woollcott ['W-iz-ooll', 'cott']
# woollen ['w-iz-ool', 'len']
# woolley ['W-iz-ool', 'ley']
# woolly ['w-iz-ool', 'ly']
# woolman ['w-iz-ool', 'man']
# woolsey ['w-iz-ool', 'sey']
# woolworth ['W-iz-ool', 'worth']
# wooly ['w-iz-ool', 'y']
# wooster ['W-iz-oos', 'ter']
# woozy ['w-iz-ooz', 'y']
# worcester ['W-iz-orces', 'ter']
# wording ['w-iz-ord', 'ing']
# wordless ['w-iz-ord', 'less']
# wordsmith ['w-iz-ord', 'smith']
# wordsworth ['W-iz-ords', 'worth']
# wordy ['w-iz-ord', 'y']
# workbench ['w-iz-ork', 'bench']
# workday ['w-iz-ork', 'day']
# worker ['w-iz-ork', 'er']
# workfare ['w-iz-ork', 'fare']
# workforce ['w-iz-ork', 'force']
# workhorse ['w-iz-ork', 'horse']
# working ['w-iz-ork', 'ing']
# workload ['w-iz-ork', 'load']
# workman ['w-iz-ork', 'man']
# workmen ['w-iz-ork', 'men']
# workout ['w-iz-ork', 'out']
# workplace ['w-iz-ork', 'place']
# workroom ['w-iz-ork', 'room']
# worksheet ['w-iz-ork', 'sheet']
# workshop ['w-iz-ork', 'shop']
# workweek ['w-iz-ork', 'week']
# worldly ['w-iz-orld', 'ly']
# worldwide ['w-iz-orld', 'wide']
# worldwide ['w-iz-orld', 'w-iz-ide']
# wormlike ['w-iz-orm', 'like']
# wormwood ['w-iz-orm', 'wood']
# worrel ['w-iz-or', 'rel']
# worried ['w-iz-or', 'ried']
# worries ['w-iz-or', 'ries']
# worry ['w-iz-or', 'ry']
# worsen ['w-iz-ors', 'en']
# worship ['w-iz-or', 'ship']
# worshiped ['w-iz-or', 'shiped']
# worshipped ['w-iz-or', 'shipped']
# worsted ['w-iz-or', 'sted']
# worthies ['w-iz-or', 'thies']
# worthless ['w-iz-orth', 'less']
# worthwhile ['w-iz-orth', 'while']
# worthwhile ['w-iz-orth', 'wh-iz-ile']
# worthy ['w-iz-or', 'thy']
# wortley ['W-iz-ort', 'ley']
# wotan ['W-iz-o', 'tan']
# wounded ['w-iz-ound', 'ed']
# woven ['w-iz-o', 'ven']
# wrangle ['wr-iz-an', 'gle']
# wrangled ['wr-iz-an', 'gled']
# wrapper ['wr-iz-ap', 'per']
# wrapping ['wr-iz-ap', 'ping']
# wrapup ['wr-iz-ap', 'up']
# wreckage ['wr-iz-eck', 'age']
# wrecker ['wr-iz-eck', 'er']
# wrecking ['wr-iz-eck', 'ing']
# wrenching ['wr-iz-ench', 'ing']
# wrestle ['wr-iz-es', 'tle']
# wrestled ['wr-iz-es', 'tled']
# wrestling ['wr-iz-es', 'tling']
# wretched ['wr-iz-etch', 'ed']
# wriggle ['wr-iz-ig', 'gle']
# wrigley ['Wr-iz-ig', 'ley']
# wringer ['wr-iz-ing', 'er']
# wringing ['wr-iz-ing', 'ing']
# wrinkle ['wr-iz-in', 'kle']
# wrinkled ['wr-iz-in', 'kled']
# wrinkles ['wr-iz-in', 'kles']
# wristwatch ['wr-iz-ist', 'watch']
# writer ['wr-iz-it', 'er']
# writhing ['wr-iz-ith', 'ing']
# writing ['wr-iz-it', 'ing']
# written ['wr-iz-it', 'ten']
# wrongful ['wr-iz-ong', 'ful']
# wrongly ['wr-iz-ong', 'ly']
# wryly ['wr-iz-y', 'ly']
# wryness ['wr-iz-y', 'ness']
# wyatt ['W-iz-y', 'att']
# wyeth ['W-iz-y', 'eth']
# wyler ['W-iz-y', 'ler']
# wylie ['W-iz-y', 'lie']
# x-ray [None, 'ray']
# x-rays [None, 'rays']
# xanax ['X-iz-an', 'ax']
# xebec ['x-iz-e', 'bec']
# xenon ['x-iz-e', 'non']
# xerox ['x-iz-e', 'rox']
# yachter ['-iz-yacht', 'er']
# yachting ['-iz-yacht', 'ing']
# yachtsman ['-iz-yachts', 'man']
# yager ['-iz-ya', 'ger']
# yahoo ['Y-iz-a', 'hoo']
# yahoos ['-iz-ya', 'hoos']
# yahweh ['Y-iz-ah', 'weh']
# yakov ['Y-iz-a', 'kov']
# yalta ['Y-iz-al', 'ta']
# yangtze ['Y-iz-ang', 'tze']
# yangtze ['Y-iz-ang', 'tz-iz-e']
# yankee ['Y-iz-an', 'kee']
# yardage ['-iz-yard', 'age']
# yardstick ['-iz-yard', 'stick']
# yarrow ['Y-iz-ar', 'row']
# yaupon ['-iz-yau', 'pon']
# yawner ['-iz-yawn', 'er']
# yawning ['-iz-yawn', 'ing']
# yeager ['Y-iz-ea', 'ger']
# yearbook ['-iz-year', 'book']
# yearend ['year', '-iz-end']
# yearling ['-iz-year', 'ling']
# yearlong ['-iz-year', 'long']
# yearlong ['-iz-year', 'l-iz-ong']
# yearly ['-iz-year', 'ly']
# yearning ['-iz-yearn', 'ing']
# yearnings ['-iz-yearn', 'ings']
# yelling ['-iz-yell', 'ing']
# yellow ['-iz-yel', 'low']
# yellows ['-iz-yel', 'lows']
# yeltsin ['Y-iz-el', 'tsin']
# yemen ['Y-iz-em', 'en']
# yeoman ['-iz-yeo', 'man']
# yerkes ['Y-iz-er', 'kes']
# yeses ['-iz-yes', 'es']
# yiddish ['Y-iz-id', 'dish']
# yielding ['-iz-yield', 'ing']
# yippee ['yip', 'p-iz-ee']
# yodel ['-iz-yo', 'del']
# yoga ['-iz-yo', 'ga']
# yogi ['-iz-yo', 'gi']
# yogurt ['-iz-yo', 'gurt']
# yoho ['-iz-yo', 'ho']
# yokel ['-iz-yo', 'kel']
# yonder ['-iz-yon', 'der']
# yonker ['-iz-yon', 'ker']
# yonkers ['Y-iz-on', 'kers']
# yorker ['Y-iz-ork', 'er']
# yorkers ['Y-iz-ork', 'ers']
# yorkshire ['Y-iz-ork', 'shire']
# yorktown ['Y-iz-ork', 'town']
# younger ['Y-iz-oung', 'er']
# youngest ['-iz-young', 'est']
# youngster ['-iz-young', 'ster']
# youngstown ['Y-iz-oungs', 'town']
# younker ['-iz-youn', 'ker']
# yourself ['your', 's-iz-elf']
# yourselves ['your', 's-iz-elves']
# youthful ['-iz-youth', 'ful']
# yoyo ['-iz-yo', 'yo']
# yquem [None, 'quem']
# yuan ['Yu', '-iz-an']
# yucca ['-iz-yuc', 'ca']
# yucky ['-iz-yuck', 'y']
# yukon ['Y-iz-u', 'kon']
# yuletide ['-iz-yule', 'tide']
# yuma ['Y-iz-u', 'ma']
# yummies ['-iz-yum', 'mies']
# yummy ['-iz-yum', 'my']
# yuppie ['-iz-yup', 'pie']
# yury ['Y-iz-ur', 'y']
# zaftig ['z-iz-af', 'tig']
# zagreb ['Z-iz-a', 'greb']
# zaire ['Za', '-iz-ire']
# zaki ['Z-iz-ak', 'i']
# zambo ['z-iz-am', 'bo']
# zander ['z-iz-an', 'der']
# zanders ['z-iz-an', 'ders']
# zantac ['Z-iz-an', 'tac']
# zanuck ['Z-iz-an', 'uck']
# zany ['z-iz-a', 'ny']
# zapping ['z-iz-ap', 'ping']
# zealand ['Z-iz-ea', 'land']
# zealot ['z-iz-eal', 'ot']
# zealous ['z-iz-eal', 'ous']
# zebra ['z-iz-e', 'bra']
# zebras ['z-iz-e', 'bras']
# zeeman ['Z-iz-ee', 'man']
# zehner ['z-iz-eh', 'ner']
# zeitgeist ['Z-iz-eit', 'geist']
# zelda ['Z-iz-el', 'da']
# zenith ['z-iz-e', 'nith']
# zeno ['Z-iz-e', 'no']
# zero ['z-iz-e', 'ro']
# zeroed ['z-iz-e', 'roed']
# zeroes ['z-iz-e', 'roes']
# zeros ['z-iz-e', 'ros']
# zestful ['z-iz-est', 'ful']
# zeta ['z-iz-e', 'ta']
# zhejiang ['Zh-iz-e', 'jiang']
# zhejiang ['Zh-iz-e', 'j-iz-iang']
# ziegler ['Z-iz-ie', 'gler']
# zigzag ['z-iz-ig', 'zag']
# zigzagged ['z-iz-ig', 'zagged']
# zilla ['z-iz-il', 'la']
# zillah ['Z-iz-il', 'lah']
# zillion ['z-iz-il', 'lion']
# zillions ['z-iz-il', 'lions']
# zinger ['z-iz-ing', 'er']
# zion ['Z-iz-i', 'on']
# zipless ['z-iz-ip', 'less']
# zipper ['z-iz-ip', 'per']
# zippered ['z-iz-ip', 'pered']
# zippers ['z-iz-ip', 'pers']
# zipping ['z-iz-ip', 'ping']
# zippy ['z-iz-ip', 'py']
# zircon ['z-iz-ir', 'con']
# zither ['z-iz-ith', 'er']
# zloty ['zl-iz-o', 'ty']
# zlotys ['zl-iz-o', 'tys']
# zocor ['Z-iz-o', 'cor']
# zoe ['Z-iz-o', 'e']
# zola ['Z-iz-o', 'la']
# zoloft ['Z-iz-o', 'loft']
# zombie ['z-iz-om', 'bie']
# zombies ['z-iz-om', 'bies']
# zona ['Z-iz-o', 'na']
# zoning ['z-iz-on', 'ing']
# zooming ['z-iz-oom', 'ing']
# zoster ['z-iz-os', 'ter']
# zulu ['Z-iz-u', 'lu']
# zulus ['Z-iz-u', 'lus']
# zuni ['Z-iz-u', 'ni']
# zurich ['Z-iz-u', 'rich']
# zygote ['z-iz-y', 'gote']
# seeing ['s-iz-ee', 'ing']
# seeker ['s-iz-eek', 'er']
# seekers ['s-iz-eek', 'ers']
# seeking ['s-iz-eek', 'ing']
# seeling ['s-iz-eel', 'ing']
# seely ['s-iz-ee', 'ly']
# seeming ['s-iz-eem', 'ing']
# seepage ['s-iz-eep', 'age']
# seesaw ['s-iz-ee', 'saw']
# seething ['s-iz-eeth', 'ing']
# sega ['S-iz-e', 'ga']
# segal ['S-iz-e', 'gal']
# segar ['S-iz-e', 'gar']
# segment ['s-iz-eg', 'ment']
# sego ['s-iz-e', 'go']
# seidel ['s-iz-ei', 'del']
# ...
# instill ['in', 'st-iz-ill']
# instilled ['in', 'st-iz-illed']
# instinct ['-iz-in', 'stinct']
# instruct ['in', 'str-iz-uct']
# insult ['in', 's-iz-ult']
# insults ['in', 's-iz-ults']
# insure ['in', 's-iz-ure']
# insured ['in', 's-iz-ured']
# intact ['in', 't-iz-act']
# intake ['-iz-in', 'take']
# intel ['in', 't-iz-el']
# intend ['in', 't-iz-end']
# intense ['in', 't-iz-ense']
# intent ['in', 't-iz-ent']
# inter ['in', 't-iz-er']
# intern ['-iz-in', 'tern']
# interned ['-iz-in', 'terned']
# interred ['in', 't-iz-erred']
# into ['in', 't-iz-o']
# intone ['in', 't-iz-one']
# intoned ['in', 't-iz-oned']
# intrigue ['in', 'tr-iz-igue']
# intrigued ['-iz-in', 'trigued']
# intro ['-iz-in', 'tro']
# intron ['-iz-in', 'tron']
# intros ['-iz-in', 'tros']
# intrude ['in', 'tr-iz-ude']
# inure ['in', '-iz-ure']
# inured ['in', '-iz-ured']
# invade ['in', 'v-iz-ade']
# invent ['in', 'v-iz-ent']
# inverse ['in', 'v-iz-erse']
# invert ['in', 'v-iz-ert']
# invest ['in', 'v-iz-est']
# invite ['in', 'v-iz-ite']
# invoice ['-iz-in', 'voice']
# invoke ['in', 'v-iz-oke']
# invoked ['in', 'v-iz-oked']
# involve ['in', 'v-iz-olve']
# involved ['in', 'v-iz-olved']
# inward ['-iz-in', 'ward']
# io [None, 'O']
# ion ['-iz-i', 'on']
# ira [None, 'ra']
# iran ['I', 'r-iz-an']
# iraq ['I', 'r-iz-aq']
# irate ['i', 'r-iz-ate']
# irene ['I', 'r-iz-ene']
# iris ['-iz-i', 'ris']
# irish [None, 'rish']
# irksome ['-iz-irk', 'some']
# iron ['-iz-i', 'ron']
# irons ['-iz-i', 'rons']
# irving [None, 'ving']
# irwin [None, 'win']
# isaac [None, 'saac']
# isaak ['I', 's-iz-aak']
# ishtar [None, 'tar']
# isis [None, 'sis']
# islam ['Is', 'l-iz-am']
# island ['-iz-is', 'land']
# issac [None, 'sac']
# issue ['-iz-is', 'sue']
# issued ['-iz-is', 'sued']
# isthmus ['-iz-isth', 'mus']
# itching ['-iz-itch', 'ing']
# itchy ['-iz-itch', 'y']
# item ['-iz-i', 'tem']
# itself ['it', 's-iz-elf']
# iva ['-iz-i', 'va']
# ivan [None, 'van']
# ivy [None, 'vy']
# iwo [None, 'wo']
# izard ['-iz-iz', 'ard']
# izzard ['-iz-iz', 'zard']
# jabbing ['j-iz-ab', 'bing']
# jacinth ['j-iz-a', 'cinth']
# jackal ['j-iz-ack', 'al']
# jackass ['j-iz-ack', 'ass']
# jacket ['j-iz-ack', 'et']
# jackie ['J-iz-ack', 'ie']
# jackman ['j-iz-ack', 'man']
# jackpot ['j-iz-ack', 'pot']
# jackson ['J-iz-ack', 'son']
# jacky ['j-iz-ack', 'y']
# jacob ['J-iz-a', 'cob']
# jacobs ['J-iz-a', 'cobs']
# jaded ['j-iz-ad', 'ed']
# jadeite ['j-iz-ade', 'ite']
# jaeger ['j-iz-ae', 'ger']
# jaffa ['J-iz-af', 'fa']
# jager ['j-iz-a', 'ger']
# jagger ['j-iz-ag', 'ger']
# jaguar ['j-iz-ag', 'uar']
# jailer ['j-iz-ail', 'er']
# jailhouse ['j-iz-ail', 'house']
# jaime ['J-iz-ai', 'me']
# jakie ['j-iz-a', 'kie']
# jakob ['J-iz-a', 'kob']
# jamal ['Ja', 'm-iz-al']
# jamestown ['J-iz-ames', 'town']
# jamie ['J-iz-a', 'mie']
# jamming ['j-iz-am', 'ming']
# jangle ['j-iz-an', 'gle']
# jangled ['j-iz-an', 'gled']
# janice ['J-iz-an', 'ice']
# janine ['Ja', 'n-iz-ine']
# jannock ['j-iz-an', 'nock']
# jansen ['J-iz-an', 'sen']
# janus ['J-iz-a', 'nus']
# japan ['Ja', 'p-iz-an']
# jared ['J-iz-ar', 'ed']
# jargon ['j-iz-ar', 'gon']
# jarrell ['Jar', 'r-iz-ell']
# jarring ['j-iz-ar', 'ring']
# jasmin ['j-iz-as', 'min']
# jasmine ['j-iz-as', 'mine']
# jason ['J-iz-a', 'son']
# jasper ['j-iz-as', 'per']
# jaspers ['j-iz-as', 'pers']
# jaundice ['j-iz-aun', 'dice']
# jaundiced ['j-iz-aun', 'diced']
# jaunty ['j-iz-aun', 'ty']
# java ['j-iz-a', 'va']
# jawbone ['j-iz-aw', 'bone']
# jaycee ['j-iz-ay', 'cee']
# jaycee ['j-iz-ay', 'c-iz-ee']
# jaycees ['j-iz-ay', 'cees']
# jaycees ['j-iz-ay', 'c-iz-ees']
# jayme ['J-iz-ay', 'me']
# jaymes ['J-iz-ay', 'mes']
# jaywalk ['j-iz-ay', 'walk']
# jazzman ['j-iz-azz', 'man']
# jazzmen ['j-iz-azz', 'men']
# jazzy ['j-iz-azz', 'y']
# jealous ['j-iz-eal', 'ous']
# jeanine ['Jean', '-iz-ine']
# jeepney ['j-iz-eep', 'ney']
# jeering ['j-iz-eer', 'ing']
# jeffers ['J-iz-ef', 'fers']
# jeffrey ['J-iz-ef', 'frey']
# jekyll ['J-iz-ek', 'yll']
# jellied ['j-iz-el', 'lied']
# jellies ['j-iz-el', 'lies']
# jello ['J-iz-ell', 'O']
# jelly ['j-iz-el', 'ly']
# jena ['J-iz-e', 'na']
# jenkins ['j-iz-en', 'kins']
# jenner ['J-iz-en', 'ner']
# jennie ['j-iz-en', 'nie']
# jenny ['j-iz-en', 'ny']
# jensen ['J-iz-en', 'sen']
# jerez ['Je', 'r-iz-ez']
# jerking ['j-iz-erk', 'ing']
# jerky ['j-iz-erk', 'y']
# jerry ['j-iz-er', 'ry']
# jersey ['J-iz-er', 'sey']
# jerseys ['j-iz-er', 'seys']
# jesse ['J-iz-es', 'se']
# jessie ['J-iz-es', 'sie']
# jessye ['J-iz-es', 'sye']
# jester ['j-iz-est', 'er']
# jesus ['J-iz-e', 'sus']
# jetson ['j-iz-et', 'son']
# jetted ['j-iz-et', 'ted']
# jetter ['j-iz-et', 'ter']
# jetting ['j-iz-et', 'ting']
# jetton ['j-iz-et', 'ton']
# jetty ['j-iz-et', 'ty']
# jewel ['j-iz-ew', 'el']
# jewels ['j-iz-ew', 'els']
# jewess ['J-iz-ew', 'ess']
# jewfish ['j-iz-ew', 'fish']
# jewish ['J-iz-ew', 'ish']
# jewry ['J-iz-ew', 'ry']
# jiangsu ['J-iz-iang', 'su']
# jiffy ['j-iz-if', 'fy']
# jiggle ['j-iz-ig', 'gle']
# jigsaw ['j-iz-ig', 'saw']
# jihad ['j-iz-i', 'had']
# jillion ['j-iz-il', 'lion']
# jimi ['J-iz-im', 'i']
# jimmied ['j-iz-im', 'mied']
# jimmy ['j-iz-im', 'my']
# jingle ['j-iz-in', 'gle']
# jitney ['j-iz-it', 'ney']
# jiving ['j-iz-iv', 'ing']
# joanne ['Jo', '-iz-anne']
# joaquin ['Joa', 'q-iz-uin']
# jobber ['j-iz-ob', 'ber']
# jobless ['j-iz-ob', 'less']
# jockey ['j-iz-ock', 'ey']
# jockeys ['j-iz-ock', 'eys']
# joel ['J-iz-o', 'el']
# joey ['j-iz-o', 'ey']
# joffrey ['J-iz-of', 'frey']
# jogger ['j-iz-og', 'ger']
# jogging ['j-iz-og', 'ging']
# johann ['J-iz-o', 'hann']
# johnnie ['J-iz-ohn', 'nie']
# johnny ['J-iz-ohn', 'ny']
# johnson ['J-iz-ohn', 'son']
# johnston ['J-iz-ohn', 'ston']
# johnstone ['J-iz-ohn', 'stone']
# joiner ['j-iz-oin', 'er']
# jointed ['j-iz-oint', 'ed']
# jointly ['j-iz-oint', 'ly']
# jokebook ['j-iz-oke', 'book']
# joker ['j-iz-ok', 'er']
# joking ['j-iz-ok', 'ing']
# jollies ['j-iz-ol', 'lies']
# jolly ['j-iz-ol', 'ly']
# jolson ['J-iz-ol', 'son']
# jonah ['J-iz-o', 'nah']
# jonas ['J-iz-o', 'nas']
# joneses ['J-iz-ones', 'es']
# jonestown ['J-iz-ones', 'town']
# jonson ['J-iz-on', 'son']
# joplin ['J-iz-op', 'lin']
# jordan ['J-iz-or', 'dan']
# jorden ['j-iz-or', 'den']
# jorge ['J-iz-or', 'ge']
# jose ['Jo', 's-iz-e']
# josef ['J-iz-o', 'sef']
# joseph ['J-iz-o', 'seph']
# josephs ['J-iz-o', 'sephs']
# josey ['J-iz-o', 'sey']
# josie ['J-iz-o', 'sie']
# jostle ['j-iz-os', 'tle']
# jostled ['j-iz-os', 'tled']
# jotted ['j-iz-ot', 'ted']
# journal ['j-iz-our', 'nal']
# journey ['j-iz-our', 'ney']
# journeyed ['j-iz-our', 'neyed']
# journeys ['j-iz-our', 'neys']
# jowett ['J-iz-ow', 'ett']
# jowly ['j-iz-owl', 'y']
# joyful ['j-iz-oy', 'ful']
# joyous ['j-iz-oy', 'ous']
# joyride ['j-iz-oy', 'ride']
# joystick ['j-iz-oy', 'stick']
# jr [None, 'r']
# juba ['j-iz-u', 'ba']
# judah ['J-iz-u', 'dah']
# judas ['J-iz-u', 'das']
# judgement ['j-iz-udge', 'ment']
# judges ['j-iz-udg', 'es']
# judgeship ['j-iz-udge', 'ship']
# judging ['j-iz-udg', 'ing']
# judgment ['j-iz-udg', 'ment']
# judith ['J-iz-u', 'dith']
# judo ['j-iz-u', 'do']
# judy ['J-iz-u', 'dy']
# juggle ['j-iz-ug', 'gle']
# juggled ['j-iz-ug', 'gled']
# juicy ['j-iz-uic', 'y']
# juju ['j-iz-u', 'ju']
# jukebox ['j-iz-uke', 'box']
# julep ['j-iz-u', 'lep']
# julia ['J-iz-ul', 'ia']
# julie ['J-iz-u', 'lie']
# july ['Ju', 'l-iz-y']
# jumble ['j-iz-um', 'ble']
# jumbled ['j-iz-um', 'bled']
# jumbo ['j-iz-um', 'bo']
# jumbos ['j-iz-um', 'bos']
# jumper ['j-iz-ump', 'er']
# jumping ['j-iz-ump', 'ing']
# jumpstart ['j-iz-ump', 'start']
# jumpsuit ['j-iz-ump', 'suit']
# jumpy ['j-iz-ump', 'y']
# junco ['j-iz-un', 'co']
# junction ['j-iz-unc', 'tion']
# juncture ['j-iz-unc', 'ture']
# juneau ['J-iz-u', 'neau']
# jungle ['j-iz-un', 'gle']
# junior ['j-iz-un', 'ior']
# junker ['J-iz-un', 'ker']
# junket ['j-iz-un', 'ket']
# junkie ['j-iz-unk', 'ie']
# junkies ['j-iz-unk', 'ies']
# junky ['j-iz-unk', 'y']
# junkyard ['j-iz-unk', 'yard']
# juno ['J-iz-u', 'no']
# junta ['j-iz-un', 'ta']
# juries ['j-iz-u', 'ries']
# jurist ['j-iz-u', 'rist']
# juror ['j-iz-u', 'ror']
# jury ['j-iz-u', 'ry']
# juster ['j-iz-ust', 'er']
# justice ['j-iz-us', 'tice']
# justin ['J-iz-us', 'tin']
# justly ['j-iz-ust', 'ly']
# jutland ['J-iz-ut', 'land']
# jutting ['j-iz-ut', 'ting']
# kaboom ['ka', 'b-iz-oom']
# kabul ['K-iz-a', 'bul']
# kaden ['K-iz-a', 'den']
# kafka ['K-iz-af', 'ka']
# kaiser ['k-iz-ai', 'ser']
# kalan ['k-iz-a', 'lan']
# kama ['K-iz-a', 'ma']
# kanji ['k-iz-an', 'ji']
# kansan ['K-iz-an', 'san']
# kansas ['K-iz-an', 'sas']
# kappa ['k-iz-ap', 'pa']
# karat ['k-iz-ar', 'at']
# kareem ['Kar', '-iz-eem']
# karen ['K-iz-a', 'ren']
# karin ['K-iz-ar', 'in']
# karla ['K-iz-ar', 'la']
# karma ['k-iz-ar', 'ma']
# karpov ['K-iz-ar', 'pov']
# karter ['K-iz-ar', 'ter']
# kashmir ['k-iz-ash', 'mir']
# kaspar ['K-iz-as', 'par']
# kasper ['K-iz-as', 'per']
# kastler ['K-iz-ast', 'ler']
# kathryn ['K-iz-ath', 'ryn']
# kathy ['K-iz-ath', 'y']
# katie ['K-iz-a', 'tie']
# katya ['K-iz-at', 'ya']
# kaufman ['K-iz-auf', 'man']
# kayak ['k-iz-ay', 'ak']
# kayla ['K-iz-ay', 'la']
# kayo ['kay', '-iz-o']
# kazakh ['K-iz-a', 'zakh']
# kazan ['K-iz-a', 'zan']
# kazoo ['ka', 'z-iz-oo']
# keaton ['K-iz-ea', 'ton']
# keegan ['K-iz-ee', 'gan']
# keeler ['K-iz-ee', 'ler']
# keeling ['k-iz-ee', 'ling']
# keelson ['k-iz-eel', 'son']
# keener ['k-iz-een', 'er']
# keenest ['k-iz-een', 'est']
# keenly ['k-iz-een', 'ly']
# keeper ['k-iz-eep', 'er']
# keeping ['k-iz-eep', 'ing']
# keepsake ['k-iz-eep', 'sake']
# keever ['k-iz-eev', 'er']
# kegler ['k-iz-eg', 'ler']
# keller ['K-iz-el', 'ler']
# kelley ['K-iz-el', 'ley']
# kellogg ['K-iz-el', 'logg']
# kelly ['K-iz-el', 'ly']
# kelsey ['K-iz-el', 'sey']
# kelson ['k-iz-el', 'son']
# kelter ['k-iz-el', 'ter']
# kelvin ['K-iz-el', 'vin']
# kenaf ['k-iz-e', 'naf']
# kendal ['k-iz-en', 'dal']
# kendall ['K-iz-en', 'dall']
# kendra ['K-iz-en', 'dra']
# kennel ['k-iz-en', 'nel']
# kenner ['K-iz-en', 'ner']
# kenneth ['K-iz-en', 'neth']
# kenning ['k-iz-en', 'ning']
# kenny ['K-iz-en', 'ny']
# keno ['k-iz-e', 'no']
# kente ['k-iz-en', 'te']
# kenya ['K-iz-en', 'ya']
# kenyan ['K-iz-en', 'yan']
# kenzie ['K-iz-en', 'zie']
# kepler ['K-iz-ep', 'ler']
# kercher ['k-iz-er', 'cher']
# kerchief ['k-iz-er', 'chief']
# kernel ['k-iz-er', 'nel']
# kernite ['k-iz-ern', 'ite']
# kerry ['k-iz-er', 'ry']
# kersey ['k-iz-er', 'sey']
# ketchup ['k-iz-etch', 'up']
# keto ['k-iz-e', 'to']
# ketone ['k-iz-e', 'tone']
# kettle ['k-iz-et', 'tle']
# kever ['k-iz-ev', 'er']
# kevin ['K-iz-ev', 'in']
# keyboard ['k-iz-ey', 'board']
# keyhole ['k-iz-ey', 'hole']
# keying ['k-iz-ey', 'ing']
# keyless ['k-iz-ey', 'less']
# keynote ['k-iz-ey', 'note']
# keypad ['k-iz-ey', 'pad']
# keystone ['k-iz-ey', 'stone']
# keystroke ['k-iz-ey', 'stroke']
# keyword ['k-iz-ey', 'word']
# khaki ['kh-iz-ak', 'i']
# khakis ['kh-iz-ak', 'is']
# khalsa ['kh-iz-al', 'sa']
# khanate ['kh-iz-an', 'ate']
# khartoum ['Khar', 't-iz-oum']
# khrushchev ['Khr-iz-u', 'shchev']
# kia ['K-iz-i', 'a']
# kibble ['k-iz-ib', 'ble']
# kibbutz ['kib', 'b-iz-utz']
# kickback ['k-iz-ick', 'back']
# kicker ['k-iz-ick', 'er']
# kickoff ['k-iz-ick', 'off']
# kidded ['k-iz-id', 'ded']
# kidder ['k-iz-id', 'der']
# kiddie ['k-iz-id', 'die']
# kiddies ['k-iz-id', 'dies']
# kidding ['k-iz-id', 'ding']
# kiddy ['k-iz-id', 'dy']
# kidnap ['k-iz-id', 'nap']
# kidnaped ['k-iz-id', 'naped']
# kidnapped ['k-iz-id', 'napped']
# kidney ['k-iz-id', 'ney']
# kidneys ['k-iz-id', 'neys']
# kiev ['Ki', '-iz-ev']
# kiley ['k-iz-i', 'ley']
# killeen ['Kil', 'l-iz-een']
# killer ['k-iz-ill', 'er']
# killing ['k-iz-ill', 'ing']
# killjoy ['k-iz-ill', 'joy']
# kilo ['k-iz-i', 'lo']
# kilos ['k-iz-i', 'los']
# kilroy ['K-iz-il', 'roy']
# kilter ['k-iz-il', 'ter']
# kimchi ['k-iz-im', 'chi']
# kimmer ['k-iz-im', 'mer']
# kinda ['k-iz-ind', 'a']
# kinder ['k-iz-ind', 'er']
# kindest ['k-iz-ind', 'est']
# kindle ['k-iz-in', 'dle']
# kindled ['k-iz-in', 'dled']
# kindling ['k-iz-in', 'dling']
# kindly ['k-iz-ind', 'ly']
# kindness ['k-iz-ind', 'ness']
# kindred ['k-iz-in', 'dred']
# kingbird ['k-iz-ing', 'bird']
# kingdom ['k-iz-ing', 'dom']
# kingly ['k-iz-ing', 'ly']
# kingpin ['k-iz-ing', 'pin']
# kingship ['k-iz-ing', 'ship']
# kingsley ['K-iz-ings', 'ley']
# kingston ['K-iz-ings', 'ton']
# kinkle ['k-iz-in', 'kle']
# kinky ['k-iz-ink', 'y']
# kinley ['K-iz-in', 'ley']
# kinsey ['K-iz-in', 'sey']
# kinship ['k-iz-in', 'ship']
# kinsley ['K-iz-ins', 'ley']
# kinsman ['k-iz-ins', 'man']
# kiosk ['k-iz-i', 'osk']
# kipling ['K-iz-ip', 'ling']
# kipper ['k-iz-ip', 'per']
# kirby ['K-iz-ir', 'by']
# kirchhoff ['K-iz-irch', 'hoff']
# kirchner ['K-iz-irch', 'ner']
# kirkman ['k-iz-irk', 'man']
# kisan ['k-iz-i', 'san']
# kismet ['k-iz-is', 'met']
# kisser ['k-iz-iss', 'er']
# kitcat ['k-iz-it', 'cat']
# kitchen ['k-iz-itch', 'en']
# kiting ['k-iz-it', 'ing']
# kittel ['k-iz-it', 'tel']
# kitten ['k-iz-it', 'ten']
# kittens ['k-iz-it', 'tens']
# kittle ['k-iz-it', 'tle']
# kitty ['k-iz-it', 'ty']
# kiwi ['k-iz-i', 'wi']
# kiwis ['k-iz-i', 'wis']
# klansmen ['Kl-iz-ans', 'men']
# kleenex ['Kl-iz-een', 'ex']
# klemens ['Kl-iz-e', 'mens']
# klezmer ['kl-iz-ez', 'mer']
# klondike ['Kl-iz-on', 'dike']
# knapper ['kn-iz-ap', 'per']
# knapsack ['kn-iz-ap', 'sack']
# kneecap ['kn-iz-ee', 'cap']
# kneeling ['kn-iz-eel', 'ing']
# knesset ['Kn-iz-es', 'set']
# knicker ['kn-iz-ick', 'er']
# knickers ['kn-iz-ick', 'ers']
# knickknack ['kn-iz-ick', 'knack']
# knifelike ['kn-iz-ife', 'like']
# knifing ['kn-iz-if', 'ing']
# knighthood ['kn-iz-ight', 'hood']
# knightly ['kn-iz-ight', 'ly']
# knitted ['kn-iz-it', 'ted']
# knitter ['kn-iz-it', 'ter']
# knitting ['kn-iz-it', 'ting']
# knittle ['kn-iz-it', 'tle']
# knitwear ['kn-iz-it', 'wear']
# knobby ['kn-iz-ob', 'by']
# knockdown ['kn-iz-ock', 'down']
# knocking ['kn-iz-ock', 'ing']
# knockout ['kn-iz-ock', 'out']
# knotted ['kn-iz-ot', 'ted']
# knotty ['kn-iz-ot', 'ty']
# knower ['kn-iz-ow', 'er']
# knowing ['kn-iz-ow', 'ing']
# knowledge ['kn-iz-owl', 'edge']
# knoxville ['Kn-iz-ox', 'ville']
# knuckle ['kn-iz-uck', 'le']
# knuckled ['kn-iz-uck', 'led']
# koba ['k-iz-o', 'ba']
# kodak ['K-iz-o', 'dak']
# koko ['k-iz-o', 'ko']
# komi ['K-iz-o', 'mi']
# kona ['k-iz-o', 'na']
# konrad ['K-iz-on', 'rad']
# kooky ['k-iz-ook', 'y']
# kopek ['k-iz-o', 'pek']
# koran ['Ko', 'r-iz-an']
# korda ['K-iz-or', 'da']
# kosher ['k-iz-o', 'sher']
# koto ['k-iz-o', 'to']
# kowtow ['k-iz-ow', 'tow']
# kowtow ['k-iz-ow', 't-iz-ow']
# krasner ['Kr-iz-as', 'ner']
# kreisler ['Kr-iz-eis', 'ler']
# kremlin ['Kr-iz-em', 'lin']
# krishna ['Kr-iz-ish', 'na']
# kroeber ['Kr-iz-oe', 'ber']
# krona ['kr-iz-o', 'na']
# krone ['kr-iz-o', 'ne']
# kronen ['kr-iz-o', 'nen']
# kroner ['kr-iz-o', 'ner']
# kronor ['kr-iz-o', 'nor']
# kronos ['Kr-iz-o', 'nos']
# kruger ['Kr-iz-u', 'ger']
# krypton ['kr-iz-yp', 'ton']
# kubrick ['K-iz-u', 'brick']
# kudos ['k-iz-u', 'dos']
# kudzu ['k-iz-ud', 'zu']
# kumquat ['k-iz-um', 'quat']
# kuna ['k-iz-u', 'na']
# kurdish ['K-iz-urd', 'ish']
# kuwait ['Ku', 'w-iz-ait']
# kuznets ['K-iz-uz', 'nets']
# kwangju ['Kwang', 'j-iz-u']
# kwanza ['kw-iz-an', 'za']
# kwanzaa ['Kw-iz-an', 'zaa']
# kyler ['K-iz-y', 'ler']
# kyoto ['K-iz-yo', 'to']
# kyra ['K-iz-y', 'ra']
# kyushu ['K-iz-yu', 'shu']
# laban ['L-iz-a', 'ban']
# label ['l-iz-a', 'bel']
# labeled ['l-iz-a', 'beled']
# labelled ['l-iz-a', 'belled']
# labor ['l-iz-a', 'bor']
# labored ['l-iz-a', 'bored']
# labour ['l-iz-a', 'bour']
# lacer ['l-iz-ac', 'er']
# laces ['l-iz-a', 'ces']
# lacey ['L-iz-ac', 'ey']
# lachlan ['L-iz-ach', 'lan']
# lackey ['l-iz-ack', 'ey']
# lackeys ['l-iz-ack', 'eys']
# lacking ['l-iz-ack', 'ing']
# lacquer ['l-iz-ac', 'quer']
# lacrosse ['la', 'cr-iz-osse']
# lactase ['l-iz-ac', 'tase']
# lactate ['l-iz-ac', 'tate']
# lactic ['l-iz-ac', 'tic']
# lactone ['l-iz-ac', 'tone']
# lactose ['l-iz-ac', 'tose']
# lacy ['L-iz-a', 'cy']
# ladder ['l-iz-ad', 'der']
# laden ['l-iz-ad', 'en']
# lader ['l-iz-ad', 'er']
# ladies ['l-iz-a', 'dies']
# lading ['l-iz-ad', 'ing']
# ladle ['l-iz-a', 'dle']
# ladled ['l-iz-a', 'dled']
# lady ['L-iz-a', 'dy']
# lafitte ['La', 'f-iz-itte']
# lagan ['l-iz-ag', 'an']
# lager ['l-iz-a', 'ger']
# laggard ['l-iz-ag', 'gard']
# lagging ['l-iz-ag', 'ging']
# lagoon ['la', 'g-iz-oon']
# lagos ['L-iz-a', 'gos']
# lahore ['La', 'h-iz-ore']
# laissez ['l-iz-ais', 'sez']
# lakefront ['l-iz-ake', 'front']
# lakeland ['L-iz-ake', 'land']
# laker ['l-iz-ak', 'er']
# lakeshore ['l-iz-ake', 'shore']
# lakeside ['l-iz-ake', 'side']
# lakin ['l-iz-a', 'kin']
# lama ['l-iz-a', 'ma']
# lamar ['La', 'm-iz-ar']
# lamas ['L-iz-a', 'mas']
# lambaste ['lam', 'b-iz-aste']
# lambda ['l-iz-amb', 'da']
# lambert ['L-iz-am', 'bert']
# lambeth ['L-iz-am', 'beth']
# lamboy ['l-iz-am', 'boy']
# /var/folders/19/lny0h34547b2y4hw36pjfgs00000gn/T/ipykernel_42004/2221370130.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iz_data['infixed'] = iz_data.apply(insert_iz, axis=1)

# %%
'''
finding data good for diddly infixation
reduplication on bisyllabic initial stress 
no reduplication on bisyllabic non-initial stress
exclude monosyllabic because coda is contested
'''

# bisyllabic + initial stress -- RED
bisyll = df[df.apply(is_bisyllabic, axis=1)]
initial_s = df[df.apply(has_initial_stress, axis=1)]
bisyll_init = pd.merge(bisyll, initial_s, how='inner', on=['word'], suffixes=('', '_remove'))
bisyll_init.drop([i for i in bisyll_init.columns if 'remove' in i], axis=1, inplace=True)

# bisyllabic + non-initial stress -- NO RED
no_initial_s = df[~df.apply(has_initial_stress, axis=1)]
bisyll_no_init = pd.merge(bisyll, no_initial_s, how='inner', on=['word'], suffixes=('', '_remove'))
bisyll_no_init.drop([i for i in bisyll_no_init.columns if 'remove' in i], axis=1, inplace=True)

diddly_data = pd.concat([bisyll_init, bisyll_no_init])
diddly_data['infixed'] = diddly_data.apply(insert_diddly, axis=1)
diddly_data.to_csv('diddly_data.csv')

# %% [markdown]
# # Creating subsets of data

# %%
expletive_df = pd.read_csv('infix_dataset/expletive_data.csv')
iz_df = pd.read_csv('infix_dataset/iz_data.csv')
diddly_df = pd.read_csv('infix_dataset/diddly_data.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
expletive_df.sample(n=200)
# Out:
#                      word  num_syllables  \
# 6329              SEDATED            3.0
# 543                AMUSED            2.0
# 1098             CONVERGE            2.0
# 6957           INTRASTATE            3.0
# 10690         HYPOTENSION            4.0
# 3771             BELITTLE            3.0
# 13379         EDITORIALLY            6.0
# 1726              PANACHE            2.0
# 8284           GELATINOUS            4.0
# 11769        COMMUNICATOR            5.0
# 2867            UNWORRIED            3.0
# 2222                LIVOR            2.0
# 3016            SOLITAIRE            3.0
# 12072          ELUCIDATED            5.0
# 4665             DICTATOR            3.0
# 701                 BAZAR            2.0
# 13229       THEATRICALITY            6.0
# 2834             UNSTATED            3.0
# 9042       DISTINGUISHING            4.0
# 10792         INADVERTENT            4.0
# 9881         PREDETERMINE            4.0
# 3116           SURFACTANT            3.0
# 3391             ALARMING            3.0
# 8271              GALATEA            4.0
# 4684              DIMITRI            3.0
# 5747            PROFUSELY            3.0
# 5032             ENGRAVER            3.0
# 52              UNCHANGED            2.0
# 10284          REVERSIBLE            4.0
# 8364         BRONTOSAURUS            4.0
# 3032             SPECIFIC            3.0
# 13371  DISPROPORTIONATELY            6.0
# 12799          HOMEOPATHY            5.0
# 12987          INEXORABLY            5.0
# 6898            INSPECTOR            3.0
# 11359       SPECTACULARLY            5.0
# 603                ASHORE            2.0
# 10811           INCOGNITO            4.0
# 3427             ALLOWING            3.0
# 3587             ARRANGER            3.0
# 5925           RECURRENCE            3.0
# 2698          UNDERSCORED            3.0
# 3326             ADMITTED            3.0
# 9449         NEVERTHELESS            4.0
# 6386              LORETTA            3.0
# 1852              PROLONG            2.0
# 1147               DECAMP            2.0
# 1804             PREDICTS            2.0
# 7460          SENSATIONAL            4.0
# 5479              PALERMO            3.0
# 11901          DEFAMATORY            5.0
# 10970          INSURGENCY            4.0
# 13697   INTERGENERATIONAL            7.0
# 3534           APPEARANCE            3.0
# 4859             DIVORCEE            3.0
# 12449       PREDOMINATING            5.0
# 3072             SUBSIDED            3.0
# 5426                OSAKA            3.0
# 138                UNSOLD            2.0
# 11513        ANENCEPHALIC            5.0
# 2877            UPHOLDING            3.0
# 6134           RESCHEDULE            3.0
# 468               AGGRESS            2.0
# 9735        PERCUSSIONIST            4.0
# 1757            PERPLEXED            2.0
# 526                AMAZED            2.0
# 13488        REEVALUATION            6.0
# 12709      MANIFESTATIONS            5.0
# 6563              MILITIA            3.0
# 7499           SOLICITOUS            4.0
# 11312      SEGREGATIONIST            5.0
# 9730               PEORIA            4.0
# 4510           DEFEASANCE            3.0
# 4142              COEQUAL            3.0
# 524               AMASSED            2.0
# 6928            INTERFERE            3.0
# 12164         EXONERATION            5.0
# 12536         REALLOCATED            5.0
# 3949            GONDOLIER            3.0
# 7978           ANTIFUNGAL            4.0
# 3492                ANITA            3.0
# 13135        ISLAMIZATION            5.0
# 9375         EXTRAVAGANCE            4.0
# 7377             VENEREAL            4.0
# 5175             EXEMPLAR            3.0
# 12532          REACTIVITY            5.0
# 942              CASSETTE            2.0
# 1565                EXCEL            2.0
# 9287             EXAMINER            4.0
# 13431         ORIGINALITY            6.0
# 12788        HERMETICALLY            5.0
# 11210          UNEDUCATED            5.0
# 11571       APPROXIMATION            5.0
# 10364          LEVITATION            4.0
# 5546             PEROXIDE            3.0
# 4027             CABOODLE            3.0
# 3092            SUGGESTED            3.0
# 2323              MISRULE            2.0
# 9861          PORNOGRAPHY            4.0
# 5102               ERODED            3.0
# 12651       REVOLUTIONIST            5.0
# 1157              DECLAIM            2.0
# 8803           DELUSIONAL            4.0
# 8292           GEOGRAPHER            4.0
# 5851             REACTIVE            3.0
# 326                 TAROT            2.0
# 2240                MAHAL            2.0
# 7462           SEPARATION            4.0
# 10591          MONOCLONAL            4.0
# 4574           DENOUEMENT            3.0
# 2039              REPLIES            2.0
# 10278           REUNITING            4.0
# 9049         DISTURBINGLY            4.0
# 5753          PROGRESSIVE            3.0
# 1270               DETACH            2.0
# 2048              REPRINT            2.0
# 1601              EXPLORE            2.0
# 4408           CORRECTIVE            3.0
# 8905             DIAGONAL            4.0
# 2425              INDULGE            2.0
# 6923            INTERBRED            3.0
# 7470           SEROLOGIST            4.0
# 3146            SYNTHETIC            3.0
# 11475         AFICIONADOS            5.0
# 7408             VIROLOGY            4.0
# 5044            ENLIGHTEN            3.0
# 5826           QUADRUPLED            3.0
# 6190           RESURFACED            3.0
# 3441             ALPHONSO            3.0
# 7536          SUBASSEMBLY            4.0
# 11398       TELECOMMUTING            5.0
# 4750            DISFIGURE            3.0
# 13368    DISINGENUOUSNESS            6.0
# 5017             ENDORSER            3.0
# 9630           OVEREXCITE            4.0
# 6728             IMMOTILE            3.0
# 4486            DECEPTIVE            3.0
# 513                 ALOFT            2.0
# 672                  BAKU            2.0
# 10187         REMEMBERING            4.0
# 508               ALLOWED            2.0
# 7451             SELENIUM            4.0
# 11550          APOLLONIAN            5.0
# 150                 UNTIL            2.0
# 12526           RADIOLOGY            5.0
# 2765            UNINJURED            3.0
# 4324           CONNIPTION            3.0
# 3036          STAGFLATION            3.0
# 4487              DECIDED            3.0
# 13539      METHODOLOGICAL            6.0
# 3973            GUARANTOR            3.0
# 12715        MANUFACTURER            5.0
# 7388            VICARIOUS            4.0
# 5819              PURSUER            3.0
# 5616              POLEMIC            3.0
# 12239          NEGOTIATED            5.0
# 13684       HETEROGENEITY            7.0
# 1463               ENCODE            2.0
# 9258            EUCALYPTI            4.0
# 11041          INTONATION            4.0
# 13495     REINDUSTRIALIZE            6.0
# 8318            GORGONIAN            4.0
# 388               ACCEDES            2.0
# 2002               REMISS            2.0
# 1240              DEPRAVE            2.0
# 5870             REASSIGN            3.0
# 12235         NECESSARILY            5.0
# 4102            CHERNOBYL            3.0
# 8421            CARTAGENA            4.0
# 4323            CONNECTOR            3.0
# 882             BOURGEOIS            2.0
# 1684                 OLAY            2.0
# 11503          AMERINDIAN            5.0
# 10626            HIBERNIA            4.0
# 12305        OCEANOGRAPHY            5.0
# 9529          OBSCENITIES            4.0
# 13138         ITINERARIES            5.0
# 11568        APPROXIMATED            5.0
# 6211           RETREADING            3.0
# 7943            ANECDOTAL            4.0
# 2084              RESTORE            2.0
# 12906        INAPPLICABLE            5.0
# 1268              DESTROY            2.0
# 2948             WHODUNIT            3.0
# 8771          DEFERENTIAL            4.0
# 8559           COMPLICITY            4.0
# 8122            AUTONOMIC            4.0
# 8770        DEFENSIVENESS            4.0
# 5732          PROCUREMENT            3.0
# 9260              EUGENIA            4.0
# 4548           DELIGHTING            3.0
# 5458            OVERTHREW            3.0
# 13559        HUMANITARIAN            6.0
# 3278            ACOUSTICS            3.0
# 10958         INSPIRATION            4.0
# 11321        SEMITROPICAL            5.0
# 13613        INTERMEDIARY            6.0
# 12153         EXCULPATORY            5.0
# 3976             GUERILLA            3.0
# 6749            IMPERILED            3.0
#
#                                            syllables  \
# 6329                             ['se', 'dat', 'ed']
# 543                                   ['a', 'mused']
# 1098                                ['con', 'verge']
# 6957                          ['in', 'tra', 'state']
# 10690                    ['hy', 'po', 'ten', 'sion']
# 3771                            ['be', 'lit', 'tle']
# 13379            ['ed', 'i', 'to', 'ri', 'al', 'ly']
# 1726                                 ['pa', 'nache']
# 8284                      ['ge', 'lat', 'i', 'nous']
# 11769               ['com', 'mu', 'ni', 'ca', 'tor']
# 2867                           ['un', 'wor', 'ried']
# 2222                                   ['li', 'vor']
# 3016                           ['sol', 'i', 'taire']
# 12072                 ['e', 'lu', 'ci', 'dat', 'ed']
# 4665                            ['dic', 'ta', 'tor']
# 701                                    ['ba', 'zar']
# 13229          ['the', 'at', 'ri', 'cal', 'i', 'ty']
# 2834                            ['un', 'stat', 'ed']
# 9042                  ['dis', 'tin', 'guish', 'ing']
# 10792                    ['in', 'ad', 'vert', 'ent']
# 9881                    ['pre', 'de', 'ter', 'mine']
# 3116                          ['sur', 'fac', 'tant']
# 3391                            ['a', 'larm', 'ing']
# 8271                         ['gal', 'a', 'te', 'a']
# 4684                             ['Di', 'mi', 'tri']
# 5747                           ['pro', 'fuse', 'ly']
# 5032                            ['en', 'grav', 'er']
# 52                                 ['un', 'changed']
# 10284                     ['re', 'vers', 'i', 'ble']
# 8364                    ['bron', 'to', 'sau', 'rus']
# 3032                            ['spe', 'cif', 'ic']
# 13371     ['dis', 'pro', 'por', 'tion', 'ate', 'ly']
# 12799                 ['ho', 'me', 'op', 'a', 'thy']
# 12987                 ['in', 'ex', 'o', 'ra', 'bly']
# 6898                           ['in', 'spec', 'tor']
# 11359              ['spec', 'tac', 'u', 'lar', 'ly']
# 603                                   ['a', 'shore']
# 10811                      ['in', 'cog', 'ni', 'to']
# 3427                            ['al', 'low', 'ing']
# 3587                            ['ar', 'rang', 'er']
# 5925                          ['re', 'cur', 'rence']
# 2698                         ['un', 'der', 'scored']
# 3326                            ['ad', 'mit', 'ted']
# 9449                    ['nev', 'er', 'the', 'less']
# 6386                             ['Lo', 'ret', 'ta']
# 1852                                 ['pro', 'long']
# 1147                                  ['de', 'camp']
# 1804                                ['pre', 'dicts']
# 7460                     ['sen', 'sa', 'tion', 'al']
# 5479                             ['Pa', 'ler', 'mo']
# 11901                 ['de', 'fam', 'a', 'to', 'ry']
# 10970                     ['in', 'sur', 'gen', 'cy']
# 13697  ['in', 'ter', 'gen', 'er', 'a', 'tion', 'al']
# 3534                          ['ap', 'pear', 'ance']
# 4859                            ['di', 'vor', 'cee']
# 12449              ['pre', 'dom', 'i', 'nat', 'ing']
# 3072                            ['sub', 'sid', 'ed']
# 5426                               ['O', 'sa', 'ka']
# 138                                   ['un', 'sold']
# 11513               ['an', 'en', 'ce', 'phal', 'ic']
# 2877                           ['up', 'hold', 'ing']
# 6134                          ['re', 'sched', 'ule']
# 468                                  ['ag', 'gress']
# 9735                   ['per', 'cus', 'sion', 'ist']
# 1757                               ['per', 'plexed']
# 526                                   ['a', 'mazed']
# 13488           ['re', 'e', 'val', 'u', 'a', 'tion']
# 12709             ['man', 'i', 'fes', 'ta', 'tions']
# 6563                             ['mi', 'li', 'tia']
# 7499                      ['so', 'lic', 'i', 'tous']
# 11312             ['seg', 're', 'ga', 'tion', 'ist']
# 9730                          ['Pe', 'o', 'ri', 'a']
# 4510                          ['de', 'fea', 'sance']
# 4142                             ['co', 'e', 'qual']
# 524                                  ['a', 'massed']
# 6928                           ['in', 'ter', 'fere']
# 12164                ['ex', 'on', 'er', 'a', 'tion']
# 12536                ['re', 'al', 'lo', 'cat', 'ed']
# 3949                           ['gon', 'do', 'lier']
# 7978                      ['an', 'ti', 'fun', 'gal']
# 3492                               ['A', 'ni', 'ta']
# 13135               ['Is', 'lam', 'i', 'za', 'tion']
# 9375                    ['ex', 'trav', 'a', 'gance']
# 7377                        ['ve', 'ne', 're', 'al']
# 5175                            ['ex', 'em', 'plar']
# 12532                 ['re', 'ac', 'tiv', 'i', 'ty']
# 942                                 ['cas', 'sette']
# 1565                                   ['ex', 'cel']
# 9287                        ['ex', 'am', 'in', 'er']
# 13431            ['o', 'rig', 'i', 'nal', 'i', 'ty']
# 12788               ['her', 'met', 'i', 'cal', 'ly']
# 11210                 ['un', 'ed', 'u', 'cat', 'ed']
# 11571              ['ap', 'prox', 'i', 'ma', 'tion']
# 10364                     ['lev', 'i', 'ta', 'tion']
# 5546                            ['per', 'ox', 'ide']
# 4027                            ['ca', 'boo', 'dle']
# 3092                           ['sug', 'gest', 'ed']
# 2323                                 ['mis', 'rule']
# 9861                     ['por', 'nog', 'ra', 'phy']
# 5102                              ['e', 'rod', 'ed']
# 12651              ['rev', 'o', 'lu', 'tion', 'ist']
# 1157                                 ['de', 'claim']
# 8803                      ['de', 'lu', 'sion', 'al']
# 8292                      ['ge', 'og', 'ra', 'pher']
# 5851                            ['re', 'ac', 'tive']
# 326                                    ['ta', 'rot']
# 2240                                   ['ma', 'hal']
# 7462                      ['sep', 'a', 'ra', 'tion']
# 10591                     ['mon', 'o', 'clo', 'nal']
# 4574                          ['de', 'noue', 'ment']
# 2039                                 ['re', 'plies']
# 10278                      ['re', 'u', 'nit', 'ing']
# 9049                    ['dis', 'turb', 'ing', 'ly']
# 5753                         ['pro', 'gres', 'sive']
# 1270                                  ['de', 'tach']
# 2048                                 ['re', 'print']
# 1601                                 ['ex', 'plore']
# 4408                          ['cor', 'rec', 'tive']
# 8905                        ['di', 'ag', 'o', 'nal']
# 2425                                 ['in', 'dulge']
# 6923                           ['in', 'ter', 'bred']
# 7470                      ['se', 'rol', 'o', 'gist']
# 3146                           ['syn', 'thet', 'ic']
# 11475                ['a', 'fi', 'cio', 'na', 'dos']
# 7408                        ['vi', 'rol', 'o', 'gy']
# 5044                           ['en', 'light', 'en']
# 5826                          ['quad', 'ru', 'pled']
# 6190                          ['re', 'sur', 'faced']
# 3441                            ['Al', 'phon', 'so']
# 7536                     ['sub', 'as', 'sem', 'bly']
# 11398              ['tel', 'e', 'com', 'mut', 'ing']
# 4750                           ['dis', 'fig', 'ure']
# 13368       ['dis', 'in', 'gen', 'u', 'ous', 'ness']
# 5017                            ['en', 'dors', 'er']
# 9630                      ['o', 'ver', 'ex', 'cite']
# 6728                            ['im', 'mo', 'tile']
# 4486                           ['de', 'cep', 'tive']
# 513                                    ['A', 'loft']
# 672                                     ['Ba', 'ku']
# 10187                    ['re', 'mem', 'ber', 'ing']
# 508                                  ['al', 'lowed']
# 7451                        ['se', 'le', 'ni', 'um']
# 11550                 ['Ap', 'ol', 'lo', 'ni', 'an']
# 150                                    ['un', 'til']
# 12526                  ['ra', 'di', 'ol', 'o', 'gy']
# 2765                           ['un', 'in', 'jured']
# 4324                          ['con', 'nip', 'tion']
# 3036                         ['stag', 'fla', 'tion']
# 4487                             ['de', 'cid', 'ed']
# 13539         ['meth', 'od', 'o', 'log', 'i', 'cal']
# 3973                           ['guar', 'an', 'tor']
# 12715               ['man', 'u', 'fac', 'tur', 'er']
# 7388                       ['vi', 'car', 'i', 'ous']
# 5819                             ['pur', 'su', 'er']
# 5616                             ['po', 'lem', 'ic']
# 12239                 ['ne', 'go', 'ti', 'at', 'ed']
# 13684      ['het', 'er', 'o', 'ge', 'ne', 'i', 'ty']
# 1463                                  ['en', 'code']
# 9258                       ['eu', 'ca', 'lyp', 'ti']
# 11041                     ['in', 'to', 'na', 'tion']
# 13495        ['re', 'in', 'dus', 'tri', 'al', 'ize']
# 8318                       ['Gor', 'go', 'ni', 'an']
# 388                                  ['ac', 'cedes']
# 2002                                  ['re', 'miss']
# 1240                                 ['de', 'prave']
# 5870                            ['re', 'as', 'sign']
# 12235                ['nec', 'es', 'sar', 'i', 'ly']
# 4102                           ['Cher', 'no', 'byl']
# 8421                       ['Car', 'ta', 'ge', 'na']
# 4323                           ['con', 'nec', 'tor']
# 882                                ['bour', 'geois']
# 1684                                    ['o', 'lay']
# 11503                 ['Am', 'er', 'in', 'di', 'an']
# 10626                       ['Hi', 'ber', 'ni', 'a']
# 12305               ['o', 'cea', 'nog', 'ra', 'phy']
# 9529                     ['ob', 'scen', 'i', 'ties']
# 13138                ['i', 'tin', 'er', 'ar', 'ies']
# 11568               ['ap', 'prox', 'i', 'mat', 'ed']
# 6211                          ['re', 'tread', 'ing']
# 7943                       ['an', 'ec', 'do', 'tal']
# 2084                                 ['re', 'store']
# 12906               ['in', 'ap', 'pli', 'ca', 'ble']
# 1268                                 ['de', 'stroy']
# 2948                            ['who', 'dun', 'it']
# 8771                     ['def', 'er', 'en', 'tial']
# 8559                      ['com', 'plic', 'i', 'ty']
# 8122                       ['au', 'to', 'nom', 'ic']
# 8770                   ['de', 'fen', 'sive', 'ness']
# 5732                         ['pro', 'cure', 'ment']
# 9260                         ['Eu', 'ge', 'ni', 'a']
# 4548                          ['de', 'light', 'ing']
# 5458                           ['o', 'ver', 'threw']
# 13559           ['hu', 'man', 'i', 'tar', 'i', 'an']
# 3278                           ['a', 'cous', 'tics']
# 10958                    ['in', 'spi', 'ra', 'tion']
# 11321               ['sem', 'i', 'trop', 'i', 'cal']
# 13613           ['in', 'ter', 'me', 'di', 'ar', 'y']
# 12153                ['ex', 'cul', 'pa', 'to', 'ry']
# 3976                            ['gue', 'ril', 'la']
# 6749                           ['im', 'per', 'iled']
#
#                                           stress_pattern  \
# 6329            [['se', '0'], ['dat', '1'], ['ed', '0']]
# 543                         [['a', '0'], ['mused', '1']]
# 1098                      [['con', '0'], ['verge', '1']]
# 6957         [['in', '2'], ['tra', '0'], ['state', '1']]
# 10690  [['hy', '2'], ['po', '0'], ['ten', '1'], ['sio...
# 3771           [['be', '0'], ['lit', '1'], ['tle', '0']]
# 13379  [['ed', '2'], ['i', '0'], ['to', '1'], ['ri', ...
# 1726                       [['pa', '0'], ['nache', '1']]
# 8284   [['ge', '0'], ['lat', '1'], ['i', '0'], ['nous...
# 11769  [['com', '0'], ['mu', '1'], ['ni', '0'], ['ca'...
# 2867          [['un', '0'], ['wor', '1'], ['ried', '0']]
# 2222                         [['li', '0'], ['vor', '1']]
# 3016          [['sol', '2'], ['i', '0'], ['taire', '1']]
# 12072  [['e', '0'], ['lu', '1'], ['ci', '0'], ['dat',...
# 4665           [['dic', '0'], ['ta', '1'], ['tor', '0']]
# 701                          [['ba', '0'], ['zar', '1']]
# 13229  [['the', '0'], ['at', '2'], ['ri', '0'], ['cal...
# 2834           [['un', '0'], ['stat', '1'], ['ed', '0']]
# 9042   [['dis', '0'], ['tin', '1'], ['guish', '0'], [...
# 10792  [['in', '2'], ['ad', '0'], ['vert', '1'], ['en...
# 9881   [['pre', '2'], ['de', '0'], ['ter', '1'], ['mi...
# 3116         [['sur', '0'], ['fac', '1'], ['tant', '0']]
# 3391           [['a', '0'], ['larm', '1'], ['ing', '0']]
# 8271   [['gal', '2'], ['a', '0'], ['te', '1'], ['a', ...
# 4684            [['Di', '0'], ['mi', '1'], ['tri', '0']]
# 5747          [['pro', '0'], ['fuse', '1'], ['ly', '0']]
# 5032           [['en', '0'], ['grav', '1'], ['er', '0']]
# 52                       [['un', '0'], ['changed', '1']]
# 10284  [['re', '0'], ['vers', '1'], ['i', '0'], ['ble...
# 8364   [['bron', '2'], ['to', '0'], ['sau', '1'], ['r...
# 3032           [['spe', '0'], ['cif', '1'], ['ic', '0']]
# 13371  [['dis', '2'], ['pro', '0'], ['por', '1'], ['t...
# 12799  [['ho', '2'], ['me', '0'], ['op', '0'], ['a', ...
# 12987  [['in', '0'], ['ex', '1'], ['o', '0'], ['ra', ...
# 6898          [['in', '0'], ['spec', '1'], ['tor', '0']]
# 11359  [['spec', '0'], ['tac', '1'], ['u', '0'], ['la...
# 603                         [['a', '0'], ['shore', '1']]
# 10811  [['in', '0'], ['cog', '0'], ['ni', '1'], ['to'...
# 3427           [['al', '0'], ['low', '1'], ['ing', '0']]
# 3587           [['ar', '0'], ['rang', '1'], ['er', '0']]
# 5925         [['re', '0'], ['cur', '1'], ['rence', '0']]
# 2698        [['un', '2'], ['der', '0'], ['scored', '1']]
# 3326           [['ad', '0'], ['mit', '1'], ['ted', '0']]
# 9449   [['nev', '2'], ['er', '0'], ['the', '0'], ['le...
# 6386            [['Lo', '0'], ['ret', '1'], ['ta', '0']]
# 1852                       [['pro', '0'], ['long', '1']]
# 1147                        [['de', '0'], ['camp', '1']]
# 1804                      [['pre', '0'], ['dicts', '1']]
# 7460   [['sen', '0'], ['sa', '1'], ['tion', '0'], ['a...
# 5479            [['Pa', '0'], ['ler', '1'], ['mo', '0']]
# 11901  [['de', '0'], ['fam', '1'], ['a', '0'], ['to',...
# 10970  [['in', '0'], ['sur', '1'], ['gen', '0'], ['cy...
# 13697  [['in', '2'], ['ter', '0'], ['gen', '1'], ['er...
# 3534         [['ap', '0'], ['pear', '1'], ['ance', '0']]
# 4859           [['di', '0'], ['vor', '1'], ['cee', '2']]
# 12449  [['pre', '0'], ['dom', '1'], ['i', '0'], ['nat...
# 3072           [['sub', '0'], ['sid', '1'], ['ed', '0']]
# 5426              [['O', '0'], ['sa', '1'], ['ka', '0']]
# 138                         [['un', '0'], ['sold', '1']]
# 11513  [['an', '0'], ['en', '2'], ['ce', '0'], ['phal...
# 2877          [['up', '0'], ['hold', '1'], ['ing', '0']]
# 6134         [['re', '0'], ['sched', '1'], ['ule', '0']]
# 468                        [['ag', '0'], ['gress', '1']]
# 9735   [['per', '0'], ['cus', '1'], ['sion', '0'], ['...
# 1757                     [['per', '0'], ['plexed', '1']]
# 526                         [['a', '0'], ['mazed', '1']]
# 13488  [['re', '0'], ['e', '0'], ['val', '2'], ['u', ...
# 12709  [['man', '2'], ['i', '0'], ['fes', '0'], ['ta'...
# 6563            [['mi', '0'], ['li', '1'], ['tia', '0']]
# 7499   [['so', '0'], ['lic', '1'], ['i', '0'], ['tous...
# 11312  [['seg', '2'], ['re', '0'], ['ga', '1'], ['tio...
# 9730   [['Pe', '0'], ['o', '1'], ['ri', '0'], ['a', '...
# 4510         [['de', '0'], ['fea', '1'], ['sance', '0']]
# 4142            [['co', '0'], ['e', '1'], ['qual', '0']]
# 524                        [['a', '0'], ['massed', '1']]
# 6928          [['in', '2'], ['ter', '0'], ['fere', '1']]
# 12164  [['ex', '0'], ['on', '0'], ['er', '0'], ['a', ...
# 12536  [['re', '2'], ['al', '1'], ['lo', '0'], ['cat'...
# 3949          [['gon', '2'], ['do', '0'], ['lier', '1']]
# 7978   [['an', '2'], ['ti', '2'], ['fun', '1'], ['gal...
# 3492              [['A', '0'], ['ni', '1'], ['ta', '0']]
# 13135  [['Is', '2'], ['lam', '0'], ['i', '0'], ['za',...
# 9375   [['ex', '0'], ['trav', '1'], ['a', '0'], ['gan...
# 7377   [['ve', '0'], ['ne', '1'], ['re', '0'], ['al',...
# 5175           [['ex', '0'], ['em', '1'], ['plar', '0']]
# 12532  [['re', '2'], ['ac', '2'], ['tiv', '1'], ['i',...
# 942                       [['cas', '0'], ['sette', '1']]
# 1565                         [['ex', '0'], ['cel', '1']]
# 9287   [['ex', '0'], ['am', '1'], ['in', '0'], ['er',...
# 13431  [['o', '0'], ['rig', '2'], ['i', '0'], ['nal',...
# 12788  [['her', '0'], ['met', '1'], ['i', '0'], ['cal...
# 11210  [['un', '0'], ['ed', '1'], ['u', '0'], ['cat',...
# 11571  [['ap', '0'], ['prox', '2'], ['i', '0'], ['ma'...
# 10364  [['lev', '2'], ['i', '0'], ['ta', '1'], ['tion...
# 5546           [['per', '0'], ['ox', '1'], ['ide', '2']]
# 4027           [['ca', '0'], ['boo', '1'], ['dle', '0']]
# 3092          [['sug', '0'], ['gest', '1'], ['ed', '0']]
# 2323                       [['mis', '0'], ['rule', '1']]
# 9861   [['por', '0'], ['nog', '1'], ['ra', '0'], ['ph...
# 5102             [['e', '0'], ['rod', '1'], ['ed', '0']]
# 12651  [['rev', '2'], ['o', '0'], ['lu', '1'], ['tion...
# 1157                       [['de', '0'], ['claim', '1']]
# 8803   [['de', '0'], ['lu', '1'], ['sion', '0'], ['al...
# 8292   [['ge', '0'], ['og', '1'], ['ra', '0'], ['pher...
# 5851           [['re', '0'], ['ac', '1'], ['tive', '0']]
# 326                          [['ta', '2'], ['rot', '1']]
# 2240                         [['ma', '0'], ['hal', '1']]
# 7462   [['sep', '2'], ['a', '0'], ['ra', '1'], ['tion...
# 10591  [['mon', '2'], ['o', '0'], ['clo', '1'], ['nal...
# 4574         [['de', '2'], ['noue', '2'], ['ment', '1']]
# 2039                       [['re', '0'], ['plies', '1']]
# 10278  [['re', '2'], ['u', '0'], ['nit', '1'], ['ing'...
# 9049   [['dis', '0'], ['turb', '1'], ['ing', '0'], ['...
# 5753        [['pro', '0'], ['gres', '1'], ['sive', '0']]
# 1270                        [['de', '0'], ['tach', '1']]
# 2048                       [['re', '0'], ['print', '1']]
# 1601                       [['ex', '0'], ['plore', '1']]
# 4408         [['cor', '0'], ['rec', '1'], ['tive', '0']]
# 8905   [['di', '0'], ['ag', '1'], ['o', '0'], ['nal',...
# 2425                       [['in', '0'], ['dulge', '1']]
# 6923          [['in', '2'], ['ter', '0'], ['bred', '1']]
# 7470   [['se', '0'], ['rol', '1'], ['o', '0'], ['gist...
# 3146          [['syn', '0'], ['thet', '1'], ['ic', '0']]
# 11475  [['a', '0'], ['fi', '2'], ['cio', '0'], ['na',...
# 7408   [['vi', '0'], ['rol', '1'], ['o', '0'], ['gy',...
# 5044          [['en', '0'], ['light', '1'], ['en', '0']]
# 5826         [['quad', '0'], ['ru', '1'], ['pled', '0']]
# 6190         [['re', '0'], ['sur', '1'], ['faced', '0']]
# 3441           [['Al', '0'], ['phon', '1'], ['so', '0']]
# 7536   [['sub', '2'], ['as', '0'], ['sem', '1'], ['bl...
# 11398  [['tel', '0'], ['e', '0'], ['com', '0'], ['mut...
# 4750          [['dis', '0'], ['fig', '1'], ['ure', '0']]
# 13368  [['dis', '2'], ['in', '0'], ['gen', '1'], ['u'...
# 5017           [['en', '0'], ['dors', '1'], ['er', '0']]
# 9630   [['o', '2'], ['ver', '0'], ['ex', '0'], ['cite...
# 6728           [['im', '0'], ['mo', '1'], ['tile', '0']]
# 4486          [['de', '0'], ['cep', '1'], ['tive', '0']]
# 513                          [['A', '0'], ['loft', '1']]
# 672                           [['Ba', '0'], ['ku', '1']]
# 10187  [['re', '0'], ['mem', '1'], ['ber', '0'], ['in...
# 508                        [['al', '0'], ['lowed', '1']]
# 7451   [['se', '0'], ['le', '1'], ['ni', '0'], ['um',...
# 11550  [['Ap', '2'], ['ol', '0'], ['lo', '1'], ['ni',...
# 150                          [['un', '0'], ['til', '1']]
# 12526  [['ra', '2'], ['di', '0'], ['ol', '1'], ['o', ...
# 2765          [['un', '0'], ['in', '1'], ['jured', '0']]
# 4324         [['con', '0'], ['nip', '1'], ['tion', '0']]
# 3036        [['stag', '0'], ['fla', '1'], ['tion', '0']]
# 4487            [['de', '0'], ['cid', '1'], ['ed', '0']]
# 13539  [['meth', '2'], ['od', '0'], ['o', '0'], ['log...
# 3973          [['guar', '2'], ['an', '0'], ['tor', '1']]
# 12715  [['man', '2'], ['u', '0'], ['fac', '1'], ['tur...
# 7388   [['vi', '0'], ['car', '1'], ['i', '0'], ['ous'...
# 5819            [['pur', '0'], ['su', '1'], ['er', '0']]
# 5616            [['po', '0'], ['lem', '1'], ['ic', '0']]
# 12239  [['ne', '0'], ['go', '1'], ['ti', '0'], ['at',...
# 13684  [['het', '2'], ['er', '0'], ['o', '0'], ['ge',...
# 1463                        [['en', '0'], ['code', '1']]
# 9258   [['eu', '2'], ['ca', '0'], ['lyp', '1'], ['ti'...
# 11041  [['in', '0'], ['to', '0'], ['na', '1'], ['tion...
# 13495  [['re', '0'], ['in', '0'], ['dus', '1'], ['tri...
# 8318   [['Gor', '0'], ['go', '1'], ['ni', '0'], ['an'...
# 388                        [['ac', '0'], ['cedes', '1']]
# 2002                        [['re', '0'], ['miss', '1']]
# 1240                       [['de', '0'], ['prave', '1']]
# 5870           [['re', '2'], ['as', '0'], ['sign', '1']]
# 12235  [['nec', '2'], ['es', '0'], ['sar', '1'], ['i'...
# 4102          [['Cher', '0'], ['no', '1'], ['byl', '0']]
# 8421   [['Car', '2'], ['ta', '0'], ['ge', '1'], ['na'...
# 4323          [['con', '0'], ['nec', '1'], ['tor', '0']]
# 882                      [['bour', '0'], ['geois', '1']]
# 1684                          [['o', '0'], ['lay', '1']]
# 11503  [['Am', '2'], ['er', '0'], ['in', '1'], ['di',...
# 10626  [['Hi', '2'], ['ber', '1'], ['ni', '0'], ['a',...
# 12305  [['o', '2'], ['cea', '0'], ['nog', '1'], ['ra'...
# 9529   [['ob', '0'], ['scen', '1'], ['i', '0'], ['tie...
# 13138  [['i', '0'], ['tin', '1'], ['er', '0'], ['ar',...
# 11568  [['ap', '0'], ['prox', '1'], ['i', '0'], ['mat...
# 6211         [['re', '0'], ['tread', '1'], ['ing', '0']]
# 7943   [['an', '2'], ['ec', '0'], ['do', '1'], ['tal'...
# 2084                       [['re', '0'], ['store', '1']]
# 12906  [['in', '0'], ['ap', '1'], ['pli', '0'], ['ca'...
# 1268                       [['de', '0'], ['stroy', '1']]
# 2948           [['who', '0'], ['dun', '1'], ['it', '0']]
# 8771   [['def', '2'], ['er', '0'], ['en', '1'], ['tia...
# 8559   [['com', '0'], ['plic', '1'], ['i', '0'], ['ty...
# 8122   [['au', '2'], ['to', '0'], ['nom', '1'], ['ic'...
# 8770   [['de', '0'], ['fen', '1'], ['sive', '0'], ['n...
# 5732        [['pro', '0'], ['cure', '1'], ['ment', '0']]
# 9260   [['Eu', '2'], ['ge', '1'], ['ni', '0'], ['a', ...
# 4548         [['de', '0'], ['light', '1'], ['ing', '0']]
# 5458          [['o', '2'], ['ver', '0'], ['threw', '1']]
# 13559  [['hu', '2'], ['man', '2'], ['i', '0'], ['tar'...
# 3278          [['a', '0'], ['cous', '1'], ['tics', '0']]
# 10958  [['in', '2'], ['spi', '0'], ['ra', '1'], ['tio...
# 11321  [['sem', '2'], ['i', '0'], ['trop', '1'], ['i'...
# 13613  [['in', '2'], ['ter', '0'], ['me', '1'], ['di'...
# 12153  [['ex', '2'], ['cul', '1'], ['pa', '0'], ['to'...
# 3976           [['gue', '0'], ['ril', '1'], ['la', '0']]
# 6749          [['im', '0'], ['per', '1'], ['iled', '0']]
#
#                                  infixed
# 6329                     se-fuckin-dated
# 543                       a-fuckin-mused
# 1098                    con-fuckin-verge
# 6957                  intra-fuckin-state
# 10690                hypo-fuckin-tension
# 3771                    be-fuckin-little
# 13379                edi-fuckin-torially
# 1726                     pa-fuckin-nache
# 8284                  ge-fuckin-latinous
# 11769               com-fuckin-municator
# 2867                   un-fuckin-worried
# 2222                       li-fuckin-vor
# 3016                   soli-fuckin-taire
# 12072                 e-fuckin-lucidated
# 4665                    dic-fuckin-tator
# 701                        ba-fuckin-zar
# 13229              theatri-fuckin-cality
# 2834                    un-fuckin-stated
# 9042              dis-fuckin-tinguishing
# 10792                inad-fuckin-vertent
# 9881                prede-fuckin-termine
# 3116                  sur-fuckin-factant
# 3391                    a-fuckin-larming
# 8271                     gala-fuckin-tea
# 4684                     Di-fuckin-mitri
# 5747                   pro-fuckin-fusely
# 5032                    en-fuckin-graver
# 52                     un-fuckin-changed
# 10284                 re-fuckin-versible
# 8364                bronto-fuckin-saurus
# 3032                    spe-fuckin-cific
# 13371         dispro-fuckin-portionately
# 12799                 homeop-fuckin-athy
# 12987                 in-fuckin-exorably
# 6898                   in-fuckin-spector
# 11359              spec-fuckin-tacularly
# 603                       a-fuckin-shore
# 10811                  incog-fuckin-nito
# 3427                    al-fuckin-lowing
# 3587                    ar-fuckin-ranger
# 5925                  re-fuckin-currence
# 2698                 under-fuckin-scored
# 3326                    ad-fuckin-mitted
# 9449                neverthe-fuckin-less
# 6386                     Lo-fuckin-retta
# 1852                     pro-fuckin-long
# 1147                      de-fuckin-camp
# 1804                    pre-fuckin-dicts
# 7460                 sen-fuckin-sational
# 5479                     Pa-fuckin-lermo
# 11901                 de-fuckin-famatory
# 10970                 in-fuckin-surgency
# 13697  inter-fuckin-gen-fuckin-erational
# 3534                  ap-fuckin-pearance
# 4859                    di-fuckin-vorcee
# 12449              pre-fuckin-dominating
# 3072                    sub-fuckin-sided
# 5426                       O-fuckin-saka
# 138                       un-fuckin-sold
# 11513               anence-fuckin-phalic
# 2877                   up-fuckin-holding
# 6134                  re-fuckin-schedule
# 468                      ag-fuckin-gress
# 9735               per-fuckin-cussionist
# 1757                   per-fuckin-plexed
# 526                       a-fuckin-mazed
# 13488               reevalu-fuckin-ation
# 12709             manifes-fuckin-tations
# 6563                     mi-fuckin-litia
# 7499                  so-fuckin-licitous
# 11312             segre-fuckin-gationist
# 9730                      Pe-fuckin-oria
# 4510                  de-fuckin-feasance
# 4142                     co-fuckin-equal
# 524                      a-fuckin-massed
# 6928                   inter-fuckin-fere
# 12164                exoner-fuckin-ation
# 12536                re-fuckin-allocated
# 3949                   gondo-fuckin-lier
# 7978                  anti-fuckin-fungal
# 3492                       A-fuckin-nita
# 13135               Islami-fuckin-zation
# 9375                ex-fuckin-travagance
# 7377                    ve-fuckin-nereal
# 5175                    ex-fuckin-emplar
# 12532                 reac-fuckin-tivity
# 942                     cas-fuckin-sette
# 1565                       ex-fuckin-cel
# 9287                    ex-fuckin-aminer
# 13431                origi-fuckin-nality
# 12788               her-fuckin-metically
# 11210                 un-fuckin-educated
# 11571              approxi-fuckin-mation
# 10364                 levi-fuckin-tation
# 5546                    per-fuckin-oxide
# 4027                    ca-fuckin-boodle
# 3092                   sug-fuckin-gested
# 2323                     mis-fuckin-rule
# 9861                 por-fuckin-nography
# 5102                      e-fuckin-roded
# 12651              revo-fuckin-lutionist
# 1157                     de-fuckin-claim
# 8803                  de-fuckin-lusional
# 8292                  ge-fuckin-ographer
# 5851                    re-fuckin-active
# 326                        ta-fuckin-rot
# 2240                       ma-fuckin-hal
# 7462                  sepa-fuckin-ration
# 10591                 mono-fuckin-clonal
# 4574                  denoue-fuckin-ment
# 2039                     re-fuckin-plies
# 10278                  reu-fuckin-niting
# 9049                dis-fuckin-turbingly
# 5753                 pro-fuckin-gressive
# 1270                      de-fuckin-tach
# 2048                     re-fuckin-print
# 1601                     ex-fuckin-plore
# 4408                  cor-fuckin-rective
# 8905                    di-fuckin-agonal
# 2425                     in-fuckin-dulge
# 6923                   inter-fuckin-bred
# 7470                  se-fuckin-rologist
# 3146                   syn-fuckin-thetic
# 11475                aficio-fuckin-nados
# 7408                    vi-fuckin-rology
# 5044                   en-fuckin-lighten
# 5826                  quad-fuckin-rupled
# 6190                  re-fuckin-surfaced
# 3441                    Al-fuckin-phonso
# 7536                 subas-fuckin-sembly
# 11398              telecom-fuckin-muting
# 4750                   dis-fuckin-figure
# 13368           disin-fuckin-genuousness
# 5017                    en-fuckin-dorser
# 9630                  overex-fuckin-cite
# 6728                    im-fuckin-motile
# 4486                   de-fuckin-ceptive
# 513                        A-fuckin-loft
# 672                         Ba-fuckin-ku
# 10187                re-fuckin-membering
# 508                      al-fuckin-lowed
# 7451                    se-fuckin-lenium
# 11550                 Apol-fuckin-lonian
# 150                        un-fuckin-til
# 12526                  radi-fuckin-ology
# 2765                   un-fuckin-injured
# 4324                  con-fuckin-niption
# 3036                 stag-fuckin-flation
# 4487                     de-fuckin-cided
# 13539             methodo-fuckin-logical
# 3973                   guaran-fuckin-tor
# 12715               manu-fuckin-facturer
# 7388                   vi-fuckin-carious
# 5819                     pur-fuckin-suer
# 5616                     po-fuckin-lemic
# 12239                 ne-fuckin-gotiated
# 13684              heteroge-fuckin-neity
# 1463                      en-fuckin-code
# 9258                   euca-fuckin-lypti
# 11041                 into-fuckin-nation
# 13495            rein-fuckin-dustrialize
# 8318                   Gor-fuckin-gonian
# 388                      ac-fuckin-cedes
# 2002                      re-fuckin-miss
# 1240                     de-fuckin-prave
# 5870                    reas-fuckin-sign
# 12235                neces-fuckin-sarily
# 4102                   Cher-fuckin-nobyl
# 8421                   Carta-fuckin-gena
# 4323                   con-fuckin-nector
# 882                    bour-fuckin-geois
# 1684                        o-fuckin-lay
# 11503                 Amer-fuckin-indian
# 10626                   Hi-fuckin-bernia
# 12305               ocea-fuckin-nography
# 9529                 ob-fuckin-scenities
# 13138                i-fuckin-tineraries
# 11568               ap-fuckin-proximated
# 6211                  re-fuckin-treading
# 7943                   anec-fuckin-dotal
# 2084                     re-fuckin-store
# 12906               in-fuckin-applicable
# 1268                     de-fuckin-stroy
# 2948                    who-fuckin-dunit
# 8771                 defer-fuckin-ential
# 8559                  com-fuckin-plicity
# 8122                   auto-fuckin-nomic
# 8770               de-fuckin-fensiveness
# 5732                 pro-fuckin-curement
# 9260                     Eu-fuckin-genia
# 4548                  de-fuckin-lighting
# 5458                   over-fuckin-threw
# 13559               humani-fuckin-tarian
# 3278                   a-fuckin-coustics
# 10958                inspi-fuckin-ration
# 11321               semi-fuckin-tropical
# 13613               inter-fuckin-mediary
# 12153                ex-fuckin-culpatory
# 3976                    gue-fuckin-rilla
# 6749                   im-fuckin-periled

# %%
indices = []

with open('expletive_indices.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        indices.append(int(row[0]))

expletive_subset = expletive_df.iloc[indices]

# %%
es_df = expletive_subset[['word', 'infixed']]
es_df['word'] = es_df['word'].str.lower()
es_df['infixed'] = es_df['infixed'].str.lower()
# Out:
# /var/folders/19/lny0h34547b2y4hw36pjfgs00000gn/T/ipykernel_73567/3812001674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   es_df['word'] = es_df['word'].str.lower()
# /var/folders/19/lny0h34547b2y4hw36pjfgs00000gn/T/ipykernel_73567/3812001674.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   es_df['infixed'] = es_df['infixed'].str.lower()

# %%
es_df.to_csv('200_expletive_examples.csv', index=False, header=False)
